# %% [markdown]
# **Context:** Cipher & Co is a brand sponsorship consultancy working with a major consumer brand preparing its next campaign. The brand wants to activate around live events — but rather than chasing a single high-profile partnership, the strategy is about presence at scale: being visible across a high volume of events in the right categories, at the right times, in the right places.
# To make that case to the brand's marketing team, Cipher & Co needs a data-backed view of where the live events calendar is most active. Which event categories generate the most activity? Which UK cities and regions see the highest concentration of events? And are there time windows — particular weeks or months — where event density spikes in ways that would amplify a campaign's reach?
# Your team has been brought in to map that landscape. The work is primarily descriptive, but description in service of a decision: the output should be clear enough that Cipher & Co can walk into the brand meeting and say precisely where, when, and in what categories their client should be showing up.
#
# >**Central question to answer:** Which event categories, UK geographies, and time windows offer the highest density of live events for a brand campaign seeking maximum visibility across the events calendar?
#
# The following questions should be considered:
#
# * Which event segments and genres account for the greatest share of live event activity?
# * Where in the UK is event density highest — and does that vary meaningfully by category?
# * Are there specific time windows where event volume concentrates, and how predictable is that pattern?

# %%
import requests
import pandas
import numpy as np
import os
from dotenv import load_dotenv
from pprint import pprint
from datetime import datetime as dt

# %%
load_dotenv()

api_key = os.getenv('API_KEY')

# %%
base_url = 'https://app.ticketmaster.com/discovery/v2/'
endpoint = 'events.json'
full_url = f'{base_url}{endpoint}'
params = {
  'apikey': api_key,
  'size': 1,
  'page': 2,
  'countryCode': 'GB'
}

try:
  response = requests.get(full_url, params=params)
  response.raise_for_status()
  data = response.json()
  
except requests.exceptions.HTTPError as err:
  print(f"A HTTP error occurred: {err}")  
  
except requests.exceptions.RequestException as err:
  print(f"There was an issue with the request: {err}")

# %%
pprint(data)
# Out:
# {'_embedded': {'events': [{'_embedded': {'attractions': [{'_links': {'self': {'href': '/discovery/v2/attractions/K8vZ9171Qi7?locale=en-us'}},
#                                                           'classifications': [{'family': False,
#                                                                                'genre': {'id': 'KnvZfZ7vAv1',
#                                                                                          'name': 'Hip-Hop/Rap'},
#                                                                                'primary': True,
#                                                                                'segment': {'id': 'KZFzniwnSyZfZ7v7nJ',
#                                                                                            'name': 'Music'},
#                                                                                'subGenre': {'id': 'KZazBEonSMnZfZ7vkdA',
#                                                                                             'name': 'Urban'},
#                                                                                'subType': {'id': 'KZFzBErXgnZfZ7vAd7',
#                                                                                            'name': 'Musician'},
#                                                                                'type': {'id': 'KZAyXgnZfZ7v7la',
#                                                                                         'name': 'Individual'}}],
#                                                           'externalLinks': {'spotify': [{'url': 'https://open.spotify.com/artist/3nFkdlSjzX9mRTtwJOzDYB'}],
#                                                                             'twitter': [{'url': '@JayZ'}]},
#                                                           'id': 'K8vZ9171Qi7',
#                                                           'images': [{'fallback': False,
#                                                                       'height': 360,
#                                                                       'ratio': '16_9',
#                                                                       'url': 'https://s1.ticketm.net/dam/a/4ec/1e6d3beb-bfd6-4d63-a460-63cb6125f4ec_RETINA_PORTRAIT_16_9.jpg',
#                                                                       'width': 640},
#                                                                      {'fallback': False,
#                                                                       'height': 225,
#                                                                       'ratio': '4_3',
#                                                                       'url': 'https://s1.ticketm.net/dam/a/4ec/1e6d3beb-bfd6-4d63-a460-63cb6125f4ec_CUSTOM.jpg',
#                                                                       'width': 305},
#                                                                      {'fallback': False,
#                                                                       'height': 1365,
#                                                                       'ratio': '16_9',
#                                                                       'url': 'https://s1.ticketm.net/dam/a/4ec/1e6d3beb-bfd6-4d63-a460-63cb6125f4ec_SOURCE',
#                                                                       'width': 2426},
#                                                                      {'fallback': False,
#                                                                       'height': 683,
#                                                                       'ratio': '3_2',
#                                                                       'url': 'https://s1.ticketm.net/dam/a/4ec/1e6d3beb-bfd6-4d63-a460-63cb6125f4ec_TABLET_LANDSCAPE_3_2.jpg',
#                                                                       'width': 1024},
#                                                                      {'fallback': False,
#                                                                       'height': 576,
#                                                                       'ratio': '16_9',
#                                                                       'url': 'https://s1.ticketm.net/dam/a/4ec/1e6d3beb-bfd6-4d63-a460-63cb6125f4ec_TABLET_LANDSCAPE_16_9.jpg',
#                                                                       'width': 1024},
#                                                                      {'fallback': False,
#                                                                       'height': 639,
#                                                                       'ratio': '16_9',
#                                                                       'url': 'https://s1.ticketm.net/dam/a/4ec/1e6d3beb-bfd6-4d63-a460-63cb6125f4ec_RETINA_LANDSCAPE_16_9.jpg',
#                                                                       'width': 1136},
#                                                                      {'fallback': False,
#                                                                       'height': 203,
#                                                                       'ratio': '3_2',
#                                                                       'url': 'https://s1.ticketm.net/dam/a/4ec/1e6d3beb-bfd6-4d63-a460-63cb6125f4ec_ARTIST_PAGE_3_2.jpg',
#                                                                       'width': 305},
#                                                                      {'fallback': False,
#                                                                       'height': 427,
#                                                                       'ratio': '3_2',
#                                                                       'url': 'https://s1.ticketm.net/dam/a/4ec/1e6d3beb-bfd6-4d63-a460-63cb6125f4ec_RETINA_PORTRAIT_3_2.jpg',
#                                                                       'width': 640},
#                                                                      {'fallback': False,
#                                                                       'height': 1152,
#                                                                       'ratio': '16_9',
#                                                                       'url': 'https://s1.ticketm.net/dam/a/4ec/1e6d3beb-bfd6-4d63-a460-63cb6125f4ec_TABLET_LANDSCAPE_LARGE_16_9.jpg',
#                                                                       'width': 2048},
#                                                                      {'fallback': False,
#                                                                       'height': 115,
#                                                                       'ratio': '16_9',
#                                                                       'url': 'https://s1.ticketm.net/dam/a/4ec/1e6d3beb-bfd6-4d63-a460-63cb6125f4ec_EVENT_DETAIL_PAGE_16_9.jpg',
#                                                                       'width': 205},
#                                                                      {'fallback': False,
#                                                                       'height': 56,
#                                                                       'ratio': '16_9',
#                                                                       'url': 'https://s1.ticketm.net/dam/a/4ec/1e6d3beb-bfd6-4d63-a460-63cb6125f4ec_RECOMENDATION_16_9.jpg',
#                                                                       'width': 100}],
#                                                           'locale': 'en-us',
#                                                           'name': 'JAŸ-Z',
#                                                           'test': False,
#                                                           'type': 'attraction',
#                                                           'upcomingEvents': {'_filtered': 0,
#                                                                              '_total': 6,
#                                                                              'ticketmaster': 5,
#                                                                              'trium': 1},
#                                                           'url': 'https://www.ticketmaster.com/jayz-tickets/artist/781009'}],
#                                          'venues': [{'_links': {'self': {'href': '/discovery/v2/venues/KovZ9177OxV?locale=en-us'}},
#                                                      'ada': {'adaCustomCopy': 'Accessible '
#                                                                               'tickets '
#                                                                               'at '
#                                                                               'Tottenham '
#                                                                               'Hotspur '
#                                                                               'Stadium '
#                                                                               'are '
#                                                                               'sold '
#                                                                               'by '
#                                                                               'the '
#                                                                               'venue, '
#                                                                               'including '
#                                                                               'all '
#                                                                               'presale '
#                                                                               'tickets. \n'
#                                                                               '\n'
#                                                                               'To '
#                                                                               'help '
#                                                                               'plan '
#                                                                               'your '
#                                                                               'visit, '
#                                                                               'Accessibility '
#                                                                               'information '
#                                                                               'can '
#                                                                               'be '
#                                                                               'found '
#                                                                               'on '
#                                                                               'the '
#                                                                               'venue '
#                                                                               'using '
#                                                                               'the '
#                                                                               'below '
#                                                                               'URL:\n'
#                                                                               'https://www.tottenhamhotspurstadium.com/plan-your-visit/accessibility/ '
#                                                                               '(copy '
#                                                                               'to '
#                                                                               'browser)\n'
#                                                                               '\n'
#                                                                               '\n'
#                                                                               '\n',
#                                                              'adaHours': 'https://www.tottenhamhotspurstadium.com/plan-your-visit/accessibility/ '
#                                                                          '(copy '
#                                                                          'to '
#                                                                          'browser)',
#                                                              'adaPhones': 'https://www.tottenhamhotspurstadium.com/plan-your-visit/accessibility/ '
#                                                                           '(copy '
#                                                                           'to '
#                                                                           'browser)'},
#                                                      'address': {'line1': '782 '
#                                                                           'High '
#                                                                           'Rd'},
#                                                      'city': {'name': 'London'},
#                                                      'country': {'countryCode': 'GB',
#                                                                  'name': 'Great '
#                                                                          'Britain'},
#                                                      'dmas': [{'id': 601}],
#                                                      'id': 'KovZ9177OxV',
#                                                      'locale': 'en-us',
#                                                      'location': {'latitude': '51.60081900',
#                                                                   'longitude': '-0.06787000'},
#                                                      'markets': [{'id': '201',
#                                                                   'name': 'All '
#                                                                           'of '
#                                                                           'United '
#                                                                           'Kingdom'}],
#                                                      'name': 'Tottenham '
#                                                              'Hotspur Stadium',
#                                                      'postalCode': 'N17 0BX',
#                                                      'test': False,
#                                                      'timezone': 'Europe/London',
#                                                      'type': 'venue',
#                                                      'upcomingEvents': {'_filtered': 0,
#                                                                         '_total': 10,
#                                                                         'ticketmaster': 10},
#                                                      'url': 'https://www.ticketmaster.co.uk/tottenham-hotspur-stadium-tickets-london/venue/434396'}]},
#                            '_links': {'attractions': [{'href': '/discovery/v2/attractions/K8vZ9171Qi7?locale=en-us'}],
#                                       'self': {'href': '/discovery/v2/events/17u8v0G6CksBAD4?locale=en-us'},
#                                       'venues': [{'href': '/discovery/v2/venues/KovZ9177OxV?locale=en-us'}]},
#                            'accessibility': {'info': 'Accessible Areas - '
#                                                      'Wheelchair and Ambulant '
#                                                      'Seating Requirements for '
#                                                      'this event are sold by '
#                                                      'Tottenham Hotspur '
#                                                      'Stadium via their site '
#                                                      'click here',
#                                              'url': 'https://www.eticketing.co.uk/tottenhamhotspurstadium/EDP/Event/Index/127?spell=b809bd91-0cf6-41af-966b-45e6f82a3ed1',
#                                              'urlText': 'Click here to visit '
#                                                         'their site'},
#                            'ageRestrictions': {'legalAgeEnforced': False},
#                            'classifications': [{'family': False,
#                                                 'genre': {'id': 'KnvZfZ7vAv1',
#                                                           'name': 'Hip-Hop/Rap'},
#                                                 'primary': True,
#                                                 'segment': {'id': 'KZFzniwnSyZfZ7v7nJ',
#                                                             'name': 'Music'},
#                                                 'subGenre': {'id': 'KZazBEonSMnZfZ7vaEI',
#                                                              'name': 'Trap'},
#                                                 'subType': {'id': 'KZFzBErXgnZfZ7v7lJ',
#                                                             'name': 'Undefined'},
#                                                 'type': {'id': 'KZAyXgnZfZ7v7nI',
#                                                          'name': 'Undefined'}}],
#                            'dates': {'spanMultipleDays': False,
#                                      'start': {'dateTBA': False,
#                                                'dateTBD': False,
#                                                'dateTime': '2026-09-04T16:00:00Z',
#                                                'localDate': '2026-09-04',
#                                                'localTime': '17:00:00',
#                                                'noSpecificTime': False,
#                                                'timeTBA': False},
#                                      'status': {'code': 'offsale'},
#                                      'timezone': 'Europe/London'},
#                            'id': '17u8v0G6CksBAD4',
#                            'images': [{'fallback': False,
#                                        'height': 360,
#                                        'ratio': '16_9',
#                                        'url': 'https://s1.ticketm.net/dam/a/4ec/1e6d3beb-bfd6-4d63-a460-63cb6125f4ec_RETINA_PORTRAIT_16_9.jpg',
#                                        'width': 640},
#                                       {'fallback': False,
#                                        'height': 225,
#                                        'ratio': '4_3',
#                                        'url': 'https://s1.ticketm.net/dam/a/4ec/1e6d3beb-bfd6-4d63-a460-63cb6125f4ec_CUSTOM.jpg',
#                                        'width': 305},
#                                       {'fallback': False,
#                                        'height': 1365,
#                                        'ratio': '16_9',
#                                        'url': 'https://s1.ticketm.net/dam/a/4ec/1e6d3beb-bfd6-4d63-a460-63cb6125f4ec_SOURCE',
#                                        'width': 2426},
#                                       {'fallback': False,
#                                        'height': 683,
#                                        'ratio': '3_2',
#                                        'url': 'https://s1.ticketm.net/dam/a/4ec/1e6d3beb-bfd6-4d63-a460-63cb6125f4ec_TABLET_LANDSCAPE_3_2.jpg',
#                                        'width': 1024},
#                                       {'fallback': False,
#                                        'height': 576,
#                                        'ratio': '16_9',
#                                        'url': 'https://s1.ticketm.net/dam/a/4ec/1e6d3beb-bfd6-4d63-a460-63cb6125f4ec_TABLET_LANDSCAPE_16_9.jpg',
#                                        'width': 1024},
#                                       {'fallback': False,
#                                        'height': 639,
#                                        'ratio': '16_9',
#                                        'url': 'https://s1.ticketm.net/dam/a/4ec/1e6d3beb-bfd6-4d63-a460-63cb6125f4ec_RETINA_LANDSCAPE_16_9.jpg',
#                                        'width': 1136},
#                                       {'fallback': False,
#                                        'height': 203,
#                                        'ratio': '3_2',
#                                        'url': 'https://s1.ticketm.net/dam/a/4ec/1e6d3beb-bfd6-4d63-a460-63cb6125f4ec_ARTIST_PAGE_3_2.jpg',
#                                        'width': 305},
#                                       {'fallback': False,
#                                        'height': 427,
#                                        'ratio': '3_2',
#                                        'url': 'https://s1.ticketm.net/dam/a/4ec/1e6d3beb-bfd6-4d63-a460-63cb6125f4ec_RETINA_PORTRAIT_3_2.jpg',
#                                        'width': 640},
#                                       {'fallback': False,
#                                        'height': 1152,
#                                        'ratio': '16_9',
#                                        'url': 'https://s1.ticketm.net/dam/a/4ec/1e6d3beb-bfd6-4d63-a460-63cb6125f4ec_TABLET_LANDSCAPE_LARGE_16_9.jpg',
#                                        'width': 2048},
#                                       {'fallback': False,
#                                        'height': 115,
#                                        'ratio': '16_9',
#                                        'url': 'https://s1.ticketm.net/dam/a/4ec/1e6d3beb-bfd6-4d63-a460-63cb6125f4ec_EVENT_DETAIL_PAGE_16_9.jpg',
#                                        'width': 205},
#                                       {'fallback': False,
#                                        'height': 56,
#                                        'ratio': '16_9',
#                                        'url': 'https://s1.ticketm.net/dam/a/4ec/1e6d3beb-bfd6-4d63-a460-63cb6125f4ec_RECOMENDATION_16_9.jpg',
#                                        'width': 100}],
#                            'locale': 'en-us',
#                            'name': 'JAY-Z - 30',
#                            'nameOrigin': 'custom',
#                            'pleaseNote': 'There will be no admittance for '
#                                          'children under the age of 3 and we '
#                                          'strongly advise that children under '
#                                          'the age of 5 are not brought to '
#                                          'events at Tottenham Hotspur Stadium. '
#                                          'Please note that young children and '
#                                          'all visitors to the stadium require '
#                                          'a full priced ticket. Anyone '
#                                          'entering the stadium under the age '
#                                          'of 16 must be accompanied by an '
#                                          'adult aged 18 and above. Anyone '
#                                          'under the age of 14 is not allowed '
#                                          'onto the floor pitch area under any '
#                                          'circumstances, regardless of whether '
#                                          'they are accompanied by an adult or '
#                                          'otherwise. A max of 8 tickets per '
#                                          'person and per household applies. '
#                                          'Tickets in excess of 8 will be '
#                                          'cancelled.',
#                            'products': [{'classifications': [{'family': False,
#                                                               'genre': {'id': 'KnvZfZ7vAv1',
#                                                                         'name': 'Hip-Hop/Rap'},
#                                                               'primary': True,
#                                                               'segment': {'id': 'KZFzniwnSyZfZ7v7nJ',
#                                                                           'name': 'Music'},
#                                                               'subGenre': {'id': 'KZazBEonSMnZfZ7vaEI',
#                                                                            'name': 'Trap'},
#                                                               'subType': {'id': 'KZFzBErXgnZfZ7v7lJ',
#                                                                           'name': 'Undefined'},
#                                                               'type': {'id': 'KZAyXgnZfZ7v7nI',
#                                                                        'name': 'Undefined'}}],
#                                          'id': '17u8v0G6CrxyXUJ',
#                                          'name': 'JAY-Z - 30 - Venue '
#                                                  'Hospitality',
#                                          'type': 'VIP',
#                                          'url': 'https://www.ticketmaster.co.uk/jayz-30-venue-hospitality-london-09-04-2026/event/350064E7A2E7EDA6'}],
#                            'promoter': {'description': 'LIVE NATION UK FOR '
#                                                        'ARTIST, TOUR, FESTIVAL '
#                                                        'AND PRESALE NEWS / NTL '
#                                                        '/ GBR',
#                                         'id': '6678',
#                                         'name': 'LIVE NATION UK FOR ARTIST, '
#                                                 'TOUR, FESTIVAL AND PRESALE '
#                                                 'NEWS'},
#                            'promoters': [{'description': 'LIVE NATION UK FOR '
#                                                          'ARTIST, TOUR, '
#                                                          'FESTIVAL AND PRESALE '
#                                                          'NEWS / NTL / GBR',
#                                           'id': '6678',
#                                           'name': 'LIVE NATION UK FOR ARTIST, '
#                                                   'TOUR, FESTIVAL AND PRESALE '
#                                                   'NEWS'},
#                                          {'description': 'LIVE NATION UK FOR '
#                                                          'ARTIST, TOUR, '
#                                                          'FESTIVAL AND PRESALE '
#                                                          'NEWS / NTL / GBR',
#                                           'id': '6678',
#                                           'name': 'LIVE NATION UK FOR ARTIST, '
#                                                   'TOUR, FESTIVAL AND PRESALE '
#                                                   'NEWS'},
#                                          {'description': 'LNM - VIP NATION UK '
#                                                          '/ NTL / GBR',
#                                           'id': '3749',
#                                           'name': 'LNM - VIP NATION UK'}],
#                            'sales': {'presales': [{'description': 'Available '
#                                                                   'to O2 '
#                                                                   'Priority '
#                                                                   'Customers. '
#                                                                   'Eligible '
#                                                                   'fans must '
#                                                                   'access this '
#                                                                   'sale from '
#                                                                   'the link '
#                                                                   'below or '
#                                                                   'the O2 '
#                                                                   'Priority '
#                                                                   'app. No '
#                                                                   'presale '
#                                                                   'code is '
#                                                                   'required.',
#                                                    'endDateTime': '2026-07-10T08:00:00Z',
#                                                    'linkDescription': 'Access '
#                                                                       'Priority '
#                                                                       'from O2 '
#                                                                       'Presale',
#                                                    'name': 'Priority from O2',
#                                                    'shortDescription': 'Exclusive '
#                                                                        'Presale '
#                                                                        'for O2 '
#                                                                        'Priority '
#                                                                        'Customers',
#                                                    'startDateTime': '2026-07-09T09:00:00Z',
#                                                    'url': 'https://priority.o2.co.uk/'},
#                                                   {'endDateTime': '2026-07-10T08:00:00Z',
#                                                    'name': 'JAY-Z 30 Presale',
#                                                    'startDateTime': '2026-07-09T12:00:00Z'},
#                                                   {'description': 'Fans must '
#                                                                   'be signed '
#                                                                   'in to their '
#                                                                   'My Live '
#                                                                   'Nation '
#                                                                   'account and '
#                                                                   'access the '
#                                                                   'presale '
#                                                                   'through the '
#                                                                   'Live Nation '
#                                                                   'website. No '
#                                                                   'code '
#                                                                   'required',
#                                                    'endDateTime': '2026-07-10T08:00:00Z',
#                                                    'linkDescription': 'My Live '
#                                                                       'Nation '
#                                                                       'account',
#                                                    'name': 'Live Nation '
#                                                            'Presale',
#                                                    'shortDescription': 'Exclusive '
#                                                                        'for My '
#                                                                        'Live '
#                                                                        'Nation '
#                                                                        'Subscribers',
#                                                    'startDateTime': '2026-07-09T12:00:00Z',
#                                                    'url': 'https://www.livenation.co.uk/register/'}],
#                                      'public': {'endDateTime': '2026-09-04T22:59:00Z',
#                                                 'startDateTime': '2026-07-10T09:00:00Z',
#                                                 'startTBA': False,
#                                                 'startTBD': False}},
#                            'test': False,
#                            'ticketLimit': {'info': 'Please note: There is a '
#                                                    'ticket limit of 8 tickets '
#                                                    'per person and per credit '
#                                                    'card on this event'},
#                            'ticketTextLines': {'en-gb': {'line1': '   LIVE '
#                                                                   'NATION '
#                                                                   'PRESENTS   ',
#                                                          'line2': '          '
#                                                                   'JAY-Z           ',
#                                                          'line3': '         '
#                                                                   'JAY-Z '
#                                                                   '30         ',
#                                                          'line4': 'TOTTENHAM '
#                                                                   'HOTSPUR '
#                                                                   'STADIUM ',
#                                                          'line5': '3+/U16S '
#                                                                   'WITH '
#                                                                   '18+/STAND '
#                                                                   '14+',
#                                                          'line6': 'FRI '
#                                                                   '04-SEP-26 '
#                                                                   'DOORS '
#                                                                   '17:00 '}},
#                            'ticketing': {'allInclusivePricing': {'enabled': False},
#                                          'safeTix': {'enabled': False}},
#                            'type': 'event',
#                            'url': 'https://www.ticketmaster.co.uk/jayz-30-london-04-09-2026/event/350064E1B1E85ED5'}]},
#  '_links': {'first': {'href': '/discovery/v2/events.json?countryCode=GB&page=0&size=1'},
#             'last': {'href': '/discovery/v2/events.json?countryCode=GB&page=9999&size=1'},
#             'next': {'href': '/discovery/v2/events.json?countryCode=GB&page=3&size=1'},
#             'prev': {'href': '/discovery/v2/events.json?countryCode=GB&page=1&size=1'},
#             'self': {'href': '/discovery/v2/events.json?size=1&countryCode=GB&page=2'}},
#  'page': {'number': 2, 'size': 1, 'totalElements': 10000, 'totalPages': 10000}}

# %%
data.keys()
# Out:
# dict_keys(['_embedded', '_links', 'page'])

# %%
event_data = data['_embedded']['events'][0]
event_data
# Out:
# {'name': 'JAY-Z - 30',
#  'type': 'event',
#  'id': '17u8v0G6CksBAD4',
#  'test': False,
#  'url': 'https://www.ticketmaster.co.uk/jayz-30-london-04-09-2026/event/350064E1B1E85ED5',
#  'locale': 'en-us',
#  'images': [{'ratio': '16_9',
#    'url': 'https://s1.ticketm.net/dam/a/4ec/1e6d3beb-bfd6-4d63-a460-63cb6125f4ec_RETINA_PORTRAIT_16_9.jpg',
#    'width': 640,
#    'height': 360,
#    'fallback': False},
#   {'ratio': '4_3',
#    'url': 'https://s1.ticketm.net/dam/a/4ec/1e6d3beb-bfd6-4d63-a460-63cb6125f4ec_CUSTOM.jpg',
#    'width': 305,
#    'height': 225,
#    'fallback': False},
#   {'ratio': '16_9',
#    'url': 'https://s1.ticketm.net/dam/a/4ec/1e6d3beb-bfd6-4d63-a460-63cb6125f4ec_SOURCE',
#    'width': 2426,
#    'height': 1365,
#    'fallback': False},
#   {'ratio': '3_2',
#    'url': 'https://s1.ticketm.net/dam/a/4ec/1e6d3beb-bfd6-4d63-a460-63cb6125f4ec_TABLET_LANDSCAPE_3_2.jpg',
#    'width': 1024,
#    'height': 683,
#    'fallback': False},
#   {'ratio': '16_9',
#    'url': 'https://s1.ticketm.net/dam/a/4ec/1e6d3beb-bfd6-4d63-a460-63cb6125f4ec_TABLET_LANDSCAPE_16_9.jpg',
#    'width': 1024,
#    'height': 576,
#    'fallback': False},
#   {'ratio': '16_9',
#    'url': 'https://s1.ticketm.net/dam/a/4ec/1e6d3beb-bfd6-4d63-a460-63cb6125f4ec_RETINA_LANDSCAPE_16_9.jpg',
#    'width': 1136,
#    'height': 639,
#    'fallback': False},
#   {'ratio': '3_2',
#    'url': 'https://s1.ticketm.net/dam/a/4ec/1e6d3beb-bfd6-4d63-a460-63cb6125f4ec_ARTIST_PAGE_3_2.jpg',
#    'width': 305,
#    'height': 203,
#    'fallback': False},
#   {'ratio': '3_2',
#    'url': 'https://s1.ticketm.net/dam/a/4ec/1e6d3beb-bfd6-4d63-a460-63cb6125f4ec_RETINA_PORTRAIT_3_2.jpg',
#    'width': 640,
#    'height': 427,
#    'fallback': False},
#   {'ratio': '16_9',
#    'url': 'https://s1.ticketm.net/dam/a/4ec/1e6d3beb-bfd6-4d63-a460-63cb6125f4ec_TABLET_LANDSCAPE_LARGE_16_9.jpg',
#    'width': 2048,
#    'height': 1152,
#    'fallback': False},
#   {'ratio': '16_9',
#    'url': 'https://s1.ticketm.net/dam/a/4ec/1e6d3beb-bfd6-4d63-a460-63cb6125f4ec_EVENT_DETAIL_PAGE_16_9.jpg',
#    'width': 205,
#    'height': 115,
#    'fallback': False},
#   {'ratio': '16_9',
#    'url': 'https://s1.ticketm.net/dam/a/4ec/1e6d3beb-bfd6-4d63-a460-63cb6125f4ec_RECOMENDATION_16_9.jpg',
#    'width': 100,
#    'height': 56,
#    'fallback': False}],
#  'sales': {'public': {'startDateTime': '2026-07-10T09:00:00Z',
#    'startTBD': False,
#    'startTBA': False,
#    'endDateTime': '2026-09-04T22:59:00Z'},
#   'presales': [{'startDateTime': '2026-07-09T09:00:00Z',
#     'endDateTime': '2026-07-10T08:00:00Z',
#     'name': 'Priority from O2',
#     'description': 'Available to O2 Priority Customers. Eligible fans must access this sale from the link below or the O2 Priority app. No presale code is required.',
#     'shortDescription': 'Exclusive Presale for O2 Priority Customers',
#     'linkDescription': 'Access Priority from O2 Presale',
#     'url': 'https://priority.o2.co.uk/'},
#    {'startDateTime': '2026-07-09T12:00:00Z',
#     'endDateTime': '2026-07-10T08:00:00Z',
#     'name': 'JAY-Z 30 Presale'},
#    {'startDateTime': '2026-07-09T12:00:00Z',
#     'endDateTime': '2026-07-10T08:00:00Z',
#     'name': 'Live Nation Presale',
#     'description': 'Fans must be signed in to their My Live Nation account and access the presale through the Live Nation website. No code required',
#     'shortDescription': 'Exclusive for My Live Nation Subscribers',
#     'linkDescription': 'My Live Nation account',
#     'url': 'https://www.livenation.co.uk/register/'}]},
#  'dates': {'start': {'localDate': '2026-09-04',
#    'localTime': '17:00:00',
#    'dateTime': '2026-09-04T16:00:00Z',
#    'dateTBD': False,
#    'dateTBA': False,
#    'timeTBA': False,
#    'noSpecificTime': False},
#   'timezone': 'Europe/London',
#   'status': {'code': 'offsale'},
#   'spanMultipleDays': False},
#  'classifications': [{'primary': True,
#    'segment': {'id': 'KZFzniwnSyZfZ7v7nJ', 'name': 'Music'},
#    'genre': {'id': 'KnvZfZ7vAv1', 'name': 'Hip-Hop/Rap'},
#    'subGenre': {'id': 'KZazBEonSMnZfZ7vaEI', 'name': 'Trap'},
#    'type': {'id': 'KZAyXgnZfZ7v7nI', 'name': 'Undefined'},
#    'subType': {'id': 'KZFzBErXgnZfZ7v7lJ', 'name': 'Undefined'},
#    'family': False}],
#  'promoter': {'id': '6678',
#   'name': 'LIVE NATION UK FOR ARTIST, TOUR, FESTIVAL AND PRESALE NEWS',
#   'description': 'LIVE NATION UK FOR ARTIST, TOUR, FESTIVAL AND PRESALE NEWS / NTL / GBR'},
#  'promoters': [{'id': '6678',
#    'name': 'LIVE NATION UK FOR ARTIST, TOUR, FESTIVAL AND PRESALE NEWS',
#    'description': 'LIVE NATION UK FOR ARTIST, TOUR, FESTIVAL AND PRESALE NEWS / NTL / GBR'},
#   {'id': '6678',
#    'name': 'LIVE NATION UK FOR ARTIST, TOUR, FESTIVAL AND PRESALE NEWS',
#    'description': 'LIVE NATION UK FOR ARTIST, TOUR, FESTIVAL AND PRESALE NEWS / NTL / GBR'},
#   {'id': '3749',
#    'name': 'LNM - VIP NATION UK',
#    'description': 'LNM - VIP NATION UK / NTL / GBR'}],
#  'pleaseNote': 'There will be no admittance for children under the age of 3 and we strongly advise that children under the age of 5 are not brought to events at Tottenham Hotspur Stadium. Please note that young children and all visitors to the stadium require a full priced ticket. Anyone entering the stadium under the age of 16 must be accompanied by an adult aged 18 and above. Anyone under the age of 14 is not allowed onto the floor pitch area under any circumstances, regardless of whether they are accompanied by an adult or otherwise. A max of 8 tickets per person and per household applies. Tickets in excess of 8 will be cancelled.',
#  'products': [{'name': 'JAY-Z - 30 - Venue Hospitality',
#    'id': '17u8v0G6CrxyXUJ',
#    'url': 'https://www.ticketmaster.co.uk/jayz-30-venue-hospitality-london-09-04-2026/event/350064E7A2E7EDA6',
#    'type': 'VIP',
#    'classifications': [{'primary': True,
#      'segment': {'id': 'KZFzniwnSyZfZ7v7nJ', 'name': 'Music'},
#      'genre': {'id': 'KnvZfZ7vAv1', 'name': 'Hip-Hop/Rap'},
#      'subGenre': {'id': 'KZazBEonSMnZfZ7vaEI', 'name': 'Trap'},
#      'type': {'id': 'KZAyXgnZfZ7v7nI', 'name': 'Undefined'},
#      'subType': {'id': 'KZFzBErXgnZfZ7v7lJ', 'name': 'Undefined'},
#      'family': False}]}],
#  'accessibility': {'info': 'Accessible Areas - Wheelchair and Ambulant Seating Requirements for this event are sold by Tottenham Hotspur Stadium via their site click here',
#   'url': 'https://www.eticketing.co.uk/tottenhamhotspurstadium/EDP/Event/Index/127?spell=b809bd91-0cf6-41af-966b-45e6f82a3ed1',
#   'urlText': 'Click here to visit their site'},
#  'ticketLimit': {'info': 'Please note: There is a ticket limit of 8 tickets per person and per credit card on this event'},
#  'ageRestrictions': {'legalAgeEnforced': False},
#  'ticketing': {'safeTix': {'enabled': False},
#   'allInclusivePricing': {'enabled': False}},
#  'nameOrigin': 'custom',
#  'ticketTextLines': {'en-gb': {'line6': 'FRI 04-SEP-26 DOORS 17:00 ',
#    'line5': '3+/U16S WITH 18+/STAND 14+',
#    'line4': 'TOTTENHAM HOTSPUR STADIUM ',
#    'line3': '         JAY-Z 30         ',
#    'line2': '          JAY-Z           ',
#    'line1': '   LIVE NATION PRESENTS   '}},
#  '_links': {'self': {'href': '/discovery/v2/events/17u8v0G6CksBAD4?locale=en-us'},
#   'attractions': [{'href': '/discovery/v2/attractions/K8vZ9171Qi7?locale=en-us'}],
#   'venues': [{'href': '/discovery/v2/venues/KovZ9177OxV?locale=en-us'}]},
#  '_embedded': {'venues': [{'name': 'Tottenham Hotspur Stadium',
#     'type': 'venue',
#     'id': 'KovZ9177OxV',
#     'test': False,
#     'url': 'https://www.ticketmaster.co.uk/tottenham-hotspur-stadium-tickets-london/venue/434396',
#     'locale': 'en-us',
#     'postalCode': 'N17 0BX',
#     'timezone': 'Europe/London',
#     'city': {'name': 'London'},
#     'country': {'name': 'Great Britain', 'countryCode': 'GB'},
#     'address': {'line1': '782 High Rd'},
#     'location': {'longitude': '-0.06787000', 'latitude': '51.60081900'},
#     'markets': [{'name': 'All of United Kingdom', 'id': '201'}],
#     'dmas': [{'id': 601}],
#     'upcomingEvents': {'ticketmaster': 10, '_total': 10, '_filtered': 0},
#     'ada': {'adaPhones': 'https://www.tottenhamhotspurstadium.com/plan-your-visit/accessibility/ (copy to browser)',
#      'adaCustomCopy': 'Accessible tickets at Tottenham Hotspur Stadium are sold by the venue, including all presale tickets. \n\nTo help plan your visit, Accessibility information can be found on the venue using the below URL:\nhttps://www.tottenhamhotspurstadium.com/plan-your-visit/accessibility/ (copy to browser)\n\n\n\n',
#      'adaHours': 'https://www.tottenhamhotspurstadium.com/plan-your-visit/accessibility/ (copy to browser)'},
#     '_links': {'self': {'href': '/discovery/v2/venues/KovZ9177OxV?locale=en-us'}}}],
#   'attractions': [{'name': 'JAŸ-Z',
#     'type': 'attraction',
#     'id': 'K8vZ9171Qi7',
#     'test': False,
#     'url': 'https://www.ticketmaster.com/jayz-tickets/artist/781009',
#     'locale': 'en-us',
#     'externalLinks': {'twitter': [{'url': '@JayZ'}],
#      'spotify': [{'url': 'https://open.spotify.com/artist/3nFkdlSjzX9mRTtwJOzDYB'}]},
#     'images': [{'ratio': '16_9',
#       'url': 'https://s1.ticketm.net/dam/a/4ec/1e6d3beb-bfd6-4d63-a460-63cb6125f4ec_RETINA_PORTRAIT_16_9.jpg',
#       'width': 640,
#       'height': 360,
#       'fallback': False},
#      {'ratio': '4_3',
#       'url': 'https://s1.ticketm.net/dam/a/4ec/1e6d3beb-bfd6-4d63-a460-63cb6125f4ec_CUSTOM.jpg',
#       'width': 305,
#       'height': 225,
#       'fallback': False},
#      {'ratio': '16_9',
#       'url': 'https://s1.ticketm.net/dam/a/4ec/1e6d3beb-bfd6-4d63-a460-63cb6125f4ec_SOURCE',
#       'width': 2426,
#       'height': 1365,
#       'fallback': False},
#      {'ratio': '3_2',
#       'url': 'https://s1.ticketm.net/dam/a/4ec/1e6d3beb-bfd6-4d63-a460-63cb6125f4ec_TABLET_LANDSCAPE_3_2.jpg',
#       'width': 1024,
#       'height': 683,
#       'fallback': False},
#      {'ratio': '16_9',
#       'url': 'https://s1.ticketm.net/dam/a/4ec/1e6d3beb-bfd6-4d63-a460-63cb6125f4ec_TABLET_LANDSCAPE_16_9.jpg',
#       'width': 1024,
#       'height': 576,
#       'fallback': False},
#      {'ratio': '16_9',
#       'url': 'https://s1.ticketm.net/dam/a/4ec/1e6d3beb-bfd6-4d63-a460-63cb6125f4ec_RETINA_LANDSCAPE_16_9.jpg',
#       'width': 1136,
#       'height': 639,
#       'fallback': False},
#      {'ratio': '3_2',
#       'url': 'https://s1.ticketm.net/dam/a/4ec/1e6d3beb-bfd6-4d63-a460-63cb6125f4ec_ARTIST_PAGE_3_2.jpg',
#       'width': 305,
#       'height': 203,
#       'fallback': False},
#      {'ratio': '3_2',
#       'url': 'https://s1.ticketm.net/dam/a/4ec/1e6d3beb-bfd6-4d63-a460-63cb6125f4ec_RETINA_PORTRAIT_3_2.jpg',
#       'width': 640,
#       'height': 427,
#       'fallback': False},
#      {'ratio': '16_9',
#       'url': 'https://s1.ticketm.net/dam/a/4ec/1e6d3beb-bfd6-4d63-a460-63cb6125f4ec_TABLET_LANDSCAPE_LARGE_16_9.jpg',
#       'width': 2048,
#       'height': 1152,
#       'fallback': False},
#      {'ratio': '16_9',
#       'url': 'https://s1.ticketm.net/dam/a/4ec/1e6d3beb-bfd6-4d63-a460-63cb6125f4ec_EVENT_DETAIL_PAGE_16_9.jpg',
#       'width': 205,
#       'height': 115,
#       'fallback': False},
#      {'ratio': '16_9',
#       'url': 'https://s1.ticketm.net/dam/a/4ec/1e6d3beb-bfd6-4d63-a460-63cb6125f4ec_RECOMENDATION_16_9.jpg',
#       'width': 100,
#       'height': 56,
#       'fallback': False}],
#     'classifications': [{'primary': True,
#       'segment': {'id': 'KZFzniwnSyZfZ7v7nJ', 'name': 'Music'},
#       'genre': {'id': 'KnvZfZ7vAv1', 'name': 'Hip-Hop/Rap'},
#       'subGenre': {'id': 'KZazBEonSMnZfZ7vkdA', 'name': 'Urban'},
#       'type': {'id': 'KZAyXgnZfZ7v7la', 'name': 'Individual'},
#       'subType': {'id': 'KZFzBErXgnZfZ7vAd7', 'name': 'Musician'},
#       'family': False}],
#     'upcomingEvents': {'ticketmaster': 5,
#      'trium': 1,
#      '_total': 6,
#      '_filtered': 0},
#     '_links': {'self': {'href': '/discovery/v2/attractions/K8vZ9171Qi7?locale=en-us'}}}]}}

# %%
name = event_data['name']
name
# Out:
# 'JAY-Z - 30'

# %%
classification_data = event_data['classifications'][0]
classification_data
# Out:
# {'primary': True,
#  'segment': {'id': 'KZFzniwnSyZfZ7v7nJ', 'name': 'Music'},
#  'genre': {'id': 'KnvZfZ7vAv1', 'name': 'Hip-Hop/Rap'},
#  'subGenre': {'id': 'KZazBEonSMnZfZ7vaEI', 'name': 'Trap'},
#  'type': {'id': 'KZAyXgnZfZ7v7nI', 'name': 'Undefined'},
#  'subType': {'id': 'KZFzBErXgnZfZ7v7lJ', 'name': 'Undefined'},
#  'family': False}

# %%
segment = classification_data['segment']['name']
segment
# Out:
# 'Music'

# %%
genre = classification_data['genre']['name']
genre
# Out:
# 'Hip-Hop/Rap'

# %%
sub_genre = classification_data['subGenre']['name']
sub_genre
# Out:
# 'Trap'

# %%
type_ = classification_data['type']['name']
type_
# Out:
# 'Undefined'

# %%
sub_type = classification_data['subType']['name']
sub_type
# Out:
# 'Undefined'

# %%
sales_dates = event_data['sales']
sales_dates
# Out:
# {'public': {'startDateTime': '2026-07-10T09:00:00Z',
#   'startTBD': False,
#   'startTBA': False,
#   'endDateTime': '2026-09-04T22:59:00Z'},
#  'presales': [{'startDateTime': '2026-07-09T09:00:00Z',
#    'endDateTime': '2026-07-10T08:00:00Z',
#    'name': 'Priority from O2',
#    'description': 'Available to O2 Priority Customers. Eligible fans must access this sale from the link below or the O2 Priority app. No presale code is required.',
#    'shortDescription': 'Exclusive Presale for O2 Priority Customers',
#    'linkDescription': 'Access Priority from O2 Presale',
#    'url': 'https://priority.o2.co.uk/'},
#   {'startDateTime': '2026-07-09T12:00:00Z',
#    'endDateTime': '2026-07-10T08:00:00Z',
#    'name': 'JAY-Z 30 Presale'},
#   {'startDateTime': '2026-07-09T12:00:00Z',
#    'endDateTime': '2026-07-10T08:00:00Z',
#    'name': 'Live Nation Presale',
#    'description': 'Fans must be signed in to their My Live Nation account and access the presale through the Live Nation website. No code required',
#    'shortDescription': 'Exclusive for My Live Nation Subscribers',
#    'linkDescription': 'My Live Nation account',
#    'url': 'https://www.livenation.co.uk/register/'}]}

# %%
start_sales_date = sales_dates['public']['startDateTime']
start_sales_date = dt.fromisoformat(start_sales_date.replace('Z', '+00:00'))
start_sales_date
# Out:
# datetime.datetime(2026, 7, 10, 9, 0, tzinfo=datetime.timezone.utc)

# %%
end_sales_date = sales_dates['public']['endDateTime']
end_sales_date = dt.fromisoformat(end_sales_date.replace('Z', '+00:00'))
end_sales_date
# Out:
# datetime.datetime(2026, 9, 4, 22, 59, tzinfo=datetime.timezone.utc)

# %%
sales_period = end_sales_date - start_sales_date
sales_period
# Out:
# datetime.timedelta(days=56, seconds=50340)

# %%
venue = event_data['_embedded']['venues'][0]
venue
# Out:
# {'name': 'Tottenham Hotspur Stadium',
#  'type': 'venue',
#  'id': 'KovZ9177OxV',
#  'test': False,
#  'url': 'https://www.ticketmaster.co.uk/tottenham-hotspur-stadium-tickets-london/venue/434396',
#  'locale': 'en-us',
#  'postalCode': 'N17 0BX',
#  'timezone': 'Europe/London',
#  'city': {'name': 'London'},
#  'country': {'name': 'Great Britain', 'countryCode': 'GB'},
#  'address': {'line1': '782 High Rd'},
#  'location': {'longitude': '-0.06787000', 'latitude': '51.60081900'},
#  'markets': [{'name': 'All of United Kingdom', 'id': '201'}],
#  'dmas': [{'id': 601}],
#  'upcomingEvents': {'ticketmaster': 10, '_total': 10, '_filtered': 0},
#  'ada': {'adaPhones': 'https://www.tottenhamhotspurstadium.com/plan-your-visit/accessibility/ (copy to browser)',
#   'adaCustomCopy': 'Accessible tickets at Tottenham Hotspur Stadium are sold by the venue, including all presale tickets. \n\nTo help plan your visit, Accessibility information can be found on the venue using the below URL:\nhttps://www.tottenhamhotspurstadium.com/plan-your-visit/accessibility/ (copy to browser)\n\n\n\n',
#   'adaHours': 'https://www.tottenhamhotspurstadium.com/plan-your-visit/accessibility/ (copy to browser)'},
#  '_links': {'self': {'href': '/discovery/v2/venues/KovZ9177OxV?locale=en-us'}}}

# %%
city = venue['city']['name']
city
# Out:
# 'London'

# %%
venue_name = venue['name']
venue_name
# Out:
# 'Tottenham Hotspur Stadium'

# %%
latitude = venue['location']['latitude']
longitude = venue['location']['longitude']

longitude, latitude
# Out:
# ('-0.06787000', '51.60081900')

# %%
date_data = event_data['dates']
date_data
# Out:
# {'start': {'localDate': '2026-09-04',
#   'localTime': '17:00:00',
#   'dateTime': '2026-09-04T16:00:00Z',
#   'dateTBD': False,
#   'dateTBA': False,
#   'timeTBA': False,
#   'noSpecificTime': False},
#  'timezone': 'Europe/London',
#  'status': {'code': 'offsale'},
#  'spanMultipleDays': False}

# %%
date = date_data['start']['localDate']
date = dt.strptime(date, '%Y-%m-%d')
date
# Out:
# datetime.datetime(2026, 9, 4, 0, 0)

# %%
time = date_data['start']['localTime']
time = dt.strptime(time, '%H:%M:%S').time()
time
# Out:
# datetime.time(17, 0)

# %%
multi_day_event = date_data['spanMultipleDays']
multi_day_event
# Out:
# False

# %%
url = "https://www.wikidata.org/w/api.php"

params = {
    "action": "wbsearchentities",
    "search": venue_name,
    "language": "en",
    "format": "json"
}

headers = {
    "User-Agent": "VenueCapacityLookup/1.0"
}

try:
  response = requests.get(url, params=params, headers=headers, timeout=10)
  response.raise_for_status()

  data = response.json()

  for result in data["search"]:
      print(result["id"], result["label"])
      
except requests.exceptions.HTTPError as e:
  print(f'A HTTP Error occurred: {e}')
# Out:
# Q55074091 Tottenham Hotspur Stadium

# %%
venue_id = result['id']
venue_id
# Out:
# 'Q55074091'

# %%
result
# Out:
# {'id': 'Q55074091',
#  'title': 'Q55074091',
#  'pageid': 55148294,
#  'concepturi': 'http://www.wikidata.org/entity/Q55074091',
#  'repository': 'wikidata',
#  'url': '//www.wikidata.org/wiki/Q55074091',
#  'display': {'label': {'value': 'Tottenham Hotspur Stadium', 'language': 'en'},
#   'description': {'value': 'stadium in London, England', 'language': 'en'}},
#  'label': 'Tottenham Hotspur Stadium',
#  'description': 'stadium in London, England',
#  'match': {'type': 'label',
#   'language': 'en',
#   'text': 'Tottenham Hotspur Stadium'}}

# %%
query = f"""
SELECT ?venue ?venueLabel ?capacity WHERE {{
  # ?venue rdfs:label "{venue_name}"@en .
  OPTIONAL {{ ?venue wdt:P1083 ?capacity . }}

  SERVICE wikibase:label {{
    bd:serviceParam wikibase:language "en".
  }}
}}
"""

url = "https://query.wikidata.org/sparql"

headers = {
    "User-Agent": "VenueCapacityLookup/1.0"
}

response = requests.get(
    url,
    params={
        "query": query,
        "format": "json"
    },
    headers=headers
)

data = response.json()

for result in data["results"]["bindings"]:
    print("Venue:", result["venueLabel"]["value"])
    
    if "capacity" in result:
        print("Capacity:", result["capacity"]["value"])
    else:
        print("Capacity not found")
# Out:
# Venue: Tottenham Hotspur Stadium
# Capacity: 62850

# %%
capacity = result["capacity"]["value"]
capacity
# Out:
# '62850'

# %% [markdown]
# ## TO-DO
#
# Extract
#
#     event_id
#     name
#     date
#     time
#     multi_day_event
#     city
#     longitude
#     latitude
#     venue
#     capacity
#     segment
#     genre
#     sub_genre
#
# For each event using the Ticketmaster and Wikidata API calls. Store this as a csv file. A dataset containing 50,000 UK events in the next year should be generated.

# %%
import os
import time
import requests
from datetime import datetime, timedelta, timezone
from dotenv import load_dotenv

load_dotenv()

API_KEY  = os.getenv('API_KEY')
BASE_URL = 'https://app.ticketmaster.com/discovery/v2/events.json'

PAGE_SIZE     = 2   # max is 200 per page
MAX_PAGES     = 1    # per date window (PAGE_SIZE × MAX_PAGES = 1 event per window)
REQUEST_DELAY = 0.25  # seconds between pages — stays well inside rate limit

def build_date_windows(months: int=2, window_months: int=2) -> list[tuple[str, str]]:
    """
    Split the next `months` months into windows of `window_months` each.
    Returns (startDateTime, endDateTime) pairs in Ticketmaster's ISO 8601 format.

    A single countryCode=GB query is capped at 10,000 results. Splitting into
    bi-monthly windows gives up to 6 × 10,000 = 60,000 slots before deduplicating.
    """
    now     = datetime.now(timezone.utc).replace(hour=0, minute=0, second=0, microsecond=0)
    end_all = now + timedelta(days=30 * months)
    windows = []

    cursor = now
    while cursor < end_all:
        window_end = min(cursor + timedelta(days=30 * window_months), end_all)
        windows.append((
            cursor.strftime('%Y-%m-%dT%H:%M:%SZ'),
            window_end.strftime('%Y-%m-%dT%H:%M:%SZ'),
        ))
        cursor = window_end

    return windows

def fetch_events(
    start_dt: str,
    end_dt: str,
    seen_ids: set[str],
) -> list[dict]:
    """
    Fetch all available GB events within a single date window, paginating
    until the API has no more pages or MAX_PAGES is reached.

    Already-seen event IDs (from previous windows or a checkpoint) are
    filtered out before returning so the caller always receives only new events.

    Args:
        start_dt:  Window start in ISO 8601 format, e.g. "2026-07-08T00:00:00Z"
        end_dt:    Window end in ISO 8601 format
        seen_ids:  Set of event IDs already collected — mutated in place as
                   new IDs are encountered, so cross-window dedup is automatic.

    Returns:
        List of raw event dicts (each is the full Ticketmaster event object).
    """
    session    = requests.Session()
    new_events = []

    for page in range(MAX_PAGES):
        params = {
            'apikey':        API_KEY,
            'countryCode':   'GB',
            'startDateTime': start_dt,
            'endDateTime':   end_dt,
            'size':          PAGE_SIZE,
            'page':          page,
            'sort':          'date,asc',
        }

        try:
            response = session.get(BASE_URL, params=params, timeout=15)

            # Ticketmaster returns 429 when rate-limited — back off and retry once
            if response.status_code == 429:
                print(f'  Rate limited on page {page} — waiting 30s')
                time.sleep(30)
                response = session.get(BASE_URL, params=params, timeout=15)

            response.raise_for_status()
            data = response.json()

        except requests.exceptions.HTTPError as err:
            print(f'  HTTP error on page {page}: {err}')
            break
        except requests.exceptions.RequestException as err:
            print(f'  Request error on page {page}: {err}')
            break

        page_info   = data.get('page', {})
        total_pages = page_info.get('totalPages', 0)
        events      = data.get('_embedded', {}).get('events', [])

        if not events:
            break

        # Filter to events we haven't seen yet, then register them
        for event in events:
            event_id = event.get('id')
            if event_id and (event_id not in seen_ids): # check if event has ID and that ID has not already been seen
                seen_ids.add(event_id)
                new_events.append(event)

        print(
            f'  [{start_dt[:10]} to {end_dt[:10]}] '
            f'page {page + 1}/{total_pages} — '
            f'+{len(events)} fetched, {len(new_events)} new so far'
        )

        # Stop if we've exhausted all pages for this window
        if page + 1 >= total_pages:
            break

        time.sleep(REQUEST_DELAY)

    return new_events

# %%
build_date_windows()
# Out:
# [('2026-07-09T00:00:00Z', '2026-09-07T00:00:00Z')]

# %%
events = fetch_events(start_dt=build_date_windows()[0][0], end_dt=build_date_windows()[0][1], seen_ids=set())
events
# Out:
#   [2026-07-09 to 2026-09-07] page 1/5000 — +2 fetched, 2 new so far
# [{'name': 'Row C Start',
#   'type': 'event',
#   'id': 'ZxqgVMyxjZBYPJzwisVEJswJSIcnzynMZ6k1',
#   'test': False,
#   'url': 'https://www.eticketing.co.uk/asmglobalmanchester',
#   'locale': 'en-us',
#   'images': [{'ratio': '16_9',
#     'url': 'https://s1.ticketm.net/dam/c/8cf/a6653880-7899-4f67-8067-1f95f4d158cf_124761_EVENT_DETAIL_PAGE_16_9.jpg',
#     'width': 205,
#     'height': 115,
#     'fallback': True},
#    {'ratio': '3_2',
#     'url': 'https://s1.ticketm.net/dam/c/8cf/a6653880-7899-4f67-8067-1f95f4d158cf_124761_TABLET_LANDSCAPE_3_2.jpg',
#     'width': 1024,
#     'height': 683,
#     'fallback': True},
#    {'ratio': '16_9',
#     'url': 'https://s1.ticketm.net/dam/c/8cf/a6653880-7899-4f67-8067-1f95f4d158cf_124761_TABLET_LANDSCAPE_LARGE_16_9.jpg',
#     'width': 2048,
#     'height': 1152,
#     'fallback': True},
#    {'ratio': '4_3',
#     'url': 'https://s1.ticketm.net/dam/c/8cf/a6653880-7899-4f67-8067-1f95f4d158cf_124761_CUSTOM.jpg',
#     'width': 305,
#     'height': 225,
#     'fallback': True},
#    {'ratio': '16_9',
#     'url': 'https://s1.ticketm.net/dam/c/8cf/a6653880-7899-4f67-8067-1f95f4d158cf_124761_RETINA_LANDSCAPE_16_9.jpg',
#     'width': 1136,
#     'height': 639,
#     'fallback': True},
#    {'ratio': '3_2',
#     'url': 'https://s1.ticketm.net/dam/c/8cf/a6653880-7899-4f67-8067-1f95f4d158cf_124761_ARTIST_PAGE_3_2.jpg',
#     'width': 305,
#     'height': 203,
#     'fallback': True},
#    {'ratio': '16_9',
#     'url': 'https://s1.ticketm.net/dam/c/8cf/a6653880-7899-4f67-8067-1f95f4d158cf_124761_RETINA_PORTRAIT_16_9.jpg',
#     'width': 640,
#     'height': 360,
#     'fallback': True},
#    {'ratio': '3_2',
#     'url': 'https://s1.ticketm.net/dam/c/8cf/a6653880-7899-4f67-8067-1f95f4d158cf_124761_RETINA_PORTRAIT_3_2.jpg',
#     'width': 640,
#     'height': 427,
#     'fallback': True},
#    {'ratio': '16_9',
#     'url': 'https://s1.ticketm.net/dam/c/8cf/a6653880-7899-4f67-8067-1f95f4d158cf_124761_TABLET_LANDSCAPE_16_9.jpg',
#     'width': 1024,
#     'height': 576,
#     'fallback': True},
#    {'ratio': '16_9',
#     'url': 'https://s1.ticketm.net/dam/c/8cf/a6653880-7899-4f67-8067-1f95f4d158cf_124761_RECOMENDATION_16_9.jpg',
#     'width': 100,
#     'height': 56,
#     'fallback': True}],
#   'sales': {'public': {'startDateTime': '2023-11-24T00:00:00Z',
#     'startTBD': False,
#     'startTBA': False,
#     'endDateTime': '2027-11-24T00:00:00Z'}},
#   'dates': {'start': {'localDate': '2024-05-25',
#     'localTime': '19:30:00',
#     'dateTime': '2024-05-25T18:30:00Z',
#     'dateTBD': False,
#     'dateTBA': False,
#     'timeTBA': False,
#     'noSpecificTime': False},
#    'end': {'localDate': '2027-11-24',
#     'localTime': '00:00:00',
#     'dateTime': '2027-11-24T00:00:00Z',
#     'approximate': False,
#     'noSpecificTime': False},
#    'timezone': 'Europe/London',
#    'status': {'code': 'onsale'},
#    'spanMultipleDays': False},
#   'ticketing': {'safeTix': {'enabled': False}},
#   '_links': {'self': {'href': '/discovery/v2/events/ZxqgVMyxjZBYPJzwisVEJswJSIcnzynMZ6k1?locale=en-us'},
#    'venues': [{'href': '/discovery/v2/venues/KovZ9177A4f?locale=en-us'}]},
#   '_embedded': {'venues': [{'name': 'AO Arena',
#      'type': 'venue',
#      'id': 'KovZ9177A4f',
#      'test': False,
#      'url': 'https://www.ticketmaster.co.uk/ao-arena-tickets-manchester/venue/254336',
#      'locale': 'en-us',
#      'images': [{'ratio': '16_9',
#        'url': 'https://s1.ticketm.net/uk/dbimages/2577v.jpg',
#        'width': 205,
#        'height': 115,
#        'fallback': False}],
#      'postalCode': 'M3 1AR',
#      'timezone': 'Europe/London',
#      'city': {'name': 'Manchester'},
#      'country': {'name': 'Great Britain', 'countryCode': 'GB'},
#      'address': {'line1': 'Victoria Station, Hunts Bank'},
#      'location': {'longitude': '-2.24406600', 'latitude': '53.48816400'},
#      'markets': [{'name': 'All of United Kingdom', 'id': '201'},
#       {'name': 'Wales and North West', 'id': '205'},
#       {'name': 'North and North East', 'id': '206'}],
#      'dmas': [{'id': 601}, {'id': 605}, {'id': 606}],
#      'boxOfficeInfo': {'phoneNumberDetail': '0844 847 8000',
#       'openHoursDetail': 'The box office is situated on the Trinity Way link corridor next to the Arena Car Park entrance. This box office will be available from 1 hour before general doors open and will close 15 minutes after the main act has gone onstage. Opening times will change for Box Office depending on the time of the show. Please check https://ao-arena.com/your-visit/ prior to attending the event to ensure you have the most current up to date information.',
#       'acceptedPaymentDetail': 'Ticket purchases can be made at this box office during opening hours. Payment by all major debit/credit cards is available.',
#       'willCallDetail': "Pre-booked tickets can be collected on the day of the show from 1 hour before general doors open, up to 15 minutes after the main act goes on stage. Customers must take the credit card used / valid photo identification and the Ticketmaster reference number with them in order to collect the tickets. The cardholder will need to sign for the tickets. If you have any queries regarding box office collections, please contact Ticketmaster's customer services department."},
#      'parkingDetail': 'CitiPark, the official on-site multi-story car park has a capacity of 1,000. Visit AO Arena - Manchester | CitiPark for more information. In addition, approximately 7,000 recognised parking spaces within 10 minutes walk serve the AO Arena.',
#      'accessibleSeatingDetail': "AO Arena has been awarded GOLD status by Attitude is Everything, the disability-led charity with over 20 years' experience improving Accessible people's access to live music. Provisions have been made to cater for wheelchair users. Lifts have been installed and it is possible to enter the arena by the access link between Trinity Way and Victoria Station. The second raised tier of seating (BLK 201 and above) requires the negotiation of steep steps and so may not be suitable for the elderly, infirm or those with mobility problems. Seating at the front of the upper tier is 35ft (10m) from ground, rising to 70ft (20m) at the rear. Please email accessibility@ao-arena.com for further details.",
#      'generalInfo': {'generalRule': 'What items are NOT allowed into the arena? Backpacks, holdalls, luggage, oversized bags and cushions. (Bags larger than 35cm x 40cm x 19cm will not be permitted) No video cameras, still cameras or recording devices. No food or drink allowed. The AO Arena is a non-smoking venue, this includes e-cigarettes and vapes). In addition to these, a full list of items that are also not permitted into the arena can be reviewed here Plan Your Visit | AO Arena along with anything else which we deem to ruin the enjoyment or viewing experience of others.',
#       'childRule': "Children under the age of two are admitted free, except for children's shows where the age limit may be 12 months. If unsure check event details when booking an individual show with Ticketmaster. Children without a ticket will not be allocated a seat and must sit on the parents lap. Seated Tickets: Under 14s must be accompanied by an adult. Standing Tickets: Strictly over 14s only in the standing area, admission to the standing area will be refused to customers below this age."},
#      'upcomingEvents': {'sportxr-uk_asmglobalmanchester': 1,
#       'ticketmaster': 98,
#       '_total': 99,
#       '_filtered': 0},
#      'ada': {'adaPhones': 'If your access requirements are not met by the online booking system, please contact contactus@ao-arena.com\n\n',
#       'adaCustomCopy': 'Accessible Information - AO Arena\nAO Arena has been designed to be accessible to everyone for more information you can visit: https://www.ao-arena.com/plan-your-visit/accessibility \nAll our accessible tickets are available to be purchased online via: www.aoarena.com \nWhen you are on your events page, select Wheelchair Tickets or Ambulant Accessible Tickets, where you will be able to select your seat alongside a free personal companion ticket. \n\n',
#       'adaHours': 'The ticket office will open no later than 1 hour before doors and will not be open for new shows going on sale.\n'},
#      '_links': {'self': {'href': '/discovery/v2/venues/KovZ9177A4f?locale=en-us'}}}]}},
#  {'name': 'EVERYWHERE AT ONCE: Dewin',
#   'type': 'event',
#   'id': 'LvZ18QxAj1bZeL8vGSGnc',
#   'test': False,
#   'description': 'Everywhere At Once powered by The National Lottery presents  Dewin with support from Penne Orenne, Monarchs at The Queens Hall\n\n\nEverywhere At Once is a nationwide grassroots music festival taking place from June 26–28, 2026, spearheaded by the Music Venue Trust (MVT) and The National Lottery. It will feature over 1,200 gigs across 500+ UK grassroots venues, acting as a "festival on your doorstep" during Glastonbury\'s 2026 fallow year, aiming to support local venues.',
#   'url': 'https://www.universe.com/events/everywhere-at-once-dewin-tickets-6LTFND?ref=ticketmaster',
#   'locale': 'en-us',
#   'images': [{'ratio': '16_9',
#     'url': 'https://s1.ticketm.net/dam/c/797/5e693c26-2881-4776-8f0c-3aa94bfa3797_106511_RETINA_PORTRAIT_16_9.jpg',
#     'width': 640,
#     'height': 360,
#     'fallback': True},
#    {'ratio': '4_3',
#     'url': 'https://images.universe.com/d3a8bc1e-594f-4671-88c2-fdc233e87e5d/-/format/jpeg/-/scale_crop/305x225/center/-/progressive/yes/-/inline/yes/',
#     'width': 305,
#     'height': 225,
#     'fallback': False},
#    {'ratio': '16_9',
#     'url': 'https://s1.ticketm.net/dam/c/f50/96fa13be-e395-429b-8558-a51bb9054f50_105951_TABLET_LANDSCAPE_LARGE_16_9.jpg',
#     'width': 2048,
#     'height': 1152,
#     'fallback': True},
#    {'ratio': '3_2',
#     'url': 'https://images.universe.com/d3a8bc1e-594f-4671-88c2-fdc233e87e5d/-/format/jpeg/-/scale_crop/305x203/center/-/progressive/yes/-/inline/yes/',
#     'width': 305,
#     'height': 203,
#     'fallback': False},
#    {'ratio': '16_9',
#     'url': 'https://s1.ticketm.net/dam/c/797/5e693c26-2881-4776-8f0c-3aa94bfa3797_106511_RECOMENDATION_16_9.jpg',
#     'width': 100,
#     'height': 56,
#     'fallback': True},
#    {'ratio': '3_2',
#     'url': 'https://images.universe.com/d3a8bc1e-594f-4671-88c2-fdc233e87e5d/-/format/jpeg/-/scale_crop/1024x683/center/-/progressive/yes/-/inline/yes/',
#     'width': 1024,
#     'height': 683,
#     'fallback': False},
#    {'ratio': '16_9',
#     'url': 'https://images.universe.com/d3a8bc1e-594f-4671-88c2-fdc233e87e5d/-/format/jpeg/-/scale_crop/1024x576/center/-/progressive/yes/-/inline/yes/',
#     'width': 1024,
#     'height': 576,
#     'fallback': False},
#    {'ratio': '3_2',
#     'url': 'https://images.universe.com/d3a8bc1e-594f-4671-88c2-fdc233e87e5d/-/format/jpeg/-/scale_crop/640x427/center/-/progressive/yes/-/inline/yes/',
#     'width': 640,
#     'height': 427,
#     'fallback': False},
#    {'ratio': '16_9',
#     'url': 'https://s1.ticketm.net/dam/c/797/5e693c26-2881-4776-8f0c-3aa94bfa3797_106511_RETINA_LANDSCAPE_16_9.jpg',
#     'width': 1136,
#     'height': 639,
#     'fallback': True},
#    {'ratio': '16_9',
#     'url': 'https://s1.ticketm.net/dam/c/797/5e693c26-2881-4776-8f0c-3aa94bfa3797_106511_EVENT_DETAIL_PAGE_16_9.jpg',
#     'width': 205,
#     'height': 115,
#     'fallback': True}],
#   'sales': {'public': {'startDateTime': '2026-06-04T11:06:18Z',
#     'startTBD': False,
#     'startTBA': False,
#     'endDateTime': '2026-07-28T22:00:00Z'}},
#   'dates': {'access': {'startDateTime': '2026-06-04T11:19:14Z',
#     'startApproximate': False,
#     'endDateTime': '2026-07-28T22:00:00Z',
#     'endApproximate': False},
#    'start': {'localDate': '2026-06-28',
#     'localTime': '19:00:00',
#     'dateTime': '2026-06-28T18:00:00Z',
#     'dateTBD': False,
#     'dateTBA': False,
#     'timeTBA': False,
#     'noSpecificTime': False},
#    'end': {'localTime': '19:00:00',
#     'dateTime': '2026-07-28T22:00:00Z',
#     'approximate': False,
#     'noSpecificTime': False},
#    'timezone': 'Europe/London',
#    'status': {'code': 'onsale'},
#    'spanMultipleDays': False},
#   'classifications': [{'segment': {'id': 'KZFzniwnSyZfZ7v7nJ',
#      'name': 'Music'},
#     'genre': {'id': 'KnvZfZ7vAvv', 'name': 'Alternative'},
#     'subGenre': {'id': 'KZazBEonSMnZfZ7vAvE',
#      'name': 'Adult Alternative Pop/Rock'},
#     'family': False}],
#   'nameOrigin': 'custom',
#   '_links': {'self': {'href': '/discovery/v2/events/LvZ18QxAj1bZeL8vGSGnc?locale=en-us'},
#    'attractions': [{'href': '/discovery/v2/attractions/K8vZ917O7if?locale=en-us'},
#     {'href': '/discovery/v2/attractions/K8vZ917L9i0?locale=en-us'}],
#    'venues': [{'href': '/discovery/v2/venues/KovZ9177uRf?locale=en-us'}]},
#   '_embedded': {'venues': [{'name': 'Queens Hall',
#      'type': 'venue',
#      'id': 'KovZ9177uRf',
#      'test': False,
#      'url': 'https://www.ticketmaster.co.uk/queens-hall-tickets-narberth-pembrokeshire/venue/409995',
#      'locale': 'en-us',
#      'postalCode': 'SA67 7AS',
#      'timezone': 'Europe/London',
#      'city': {'name': 'Narberth, Pembrokeshire'},
#      'country': {'name': 'Great Britain', 'countryCode': 'GB'},
#      'address': {'line1': 'High Street'},
#      'location': {'longitude': '-4.74420400', 'latitude': '51.79891500'},
#      'markets': [{'name': 'All of United Kingdom', 'id': '201'},
#       {'name': 'Wales and North West', 'id': '205'}],
#      'dmas': [{'id': 601}, {'id': 605}],
#      'upcomingEvents': {'universe': 1, '_total': 1, '_filtered': 0},
#      '_links': {'self': {'href': '/discovery/v2/venues/KovZ9177uRf?locale=en-us'}}}],
#    'attractions': [{'name': 'Dewin',
#      'type': 'attraction',
#      'id': 'K8vZ917O7if',
#      'test': False,
#      'url': 'https://www.ticketmaster.com/dewin-tickets/artist/4412873',
#      'locale': 'en-us',
#      'externalLinks': {'spotify': [{'url': 'https://open.spotify.com/artist/1ersOZ90l0IgAQMqSDnDvu'}],
#       'instagram': [{'url': 'https://www.instagram.com/dewinband/'}]},
#      'images': [{'ratio': '16_9',
#        'url': 'https://s1.ticketm.net/dam/c/f50/96fa13be-e395-429b-8558-a51bb9054f50_105951_TABLET_LANDSCAPE_LARGE_16_9.jpg',
#        'width': 2048,
#        'height': 1152,
#        'fallback': True},
#       {'ratio': '3_2',
#        'url': 'https://s1.ticketm.net/dam/c/797/5e693c26-2881-4776-8f0c-3aa94bfa3797_106511_TABLET_LANDSCAPE_3_2.jpg',
#        'width': 1024,
#        'height': 683,
#        'fallback': True},
#       {'ratio': '3_2',
#        'url': 'https://s1.ticketm.net/dam/c/797/5e693c26-2881-4776-8f0c-3aa94bfa3797_106511_ARTIST_PAGE_3_2.jpg',
#        'width': 305,
#        'height': 203,
#        'fallback': True},
#       {'ratio': '16_9',
#        'url': 'https://s1.ticketm.net/dam/c/797/5e693c26-2881-4776-8f0c-3aa94bfa3797_106511_EVENT_DETAIL_PAGE_16_9.jpg',
#        'width': 205,
#        'height': 115,
#        'fallback': True},
#       {'ratio': '16_9',
#        'url': 'https://s1.ticketm.net/dam/c/797/5e693c26-2881-4776-8f0c-3aa94bfa3797_106511_RETINA_LANDSCAPE_16_9.jpg',
#        'width': 1136,
#        'height': 639,
#        'fallback': True},
#       {'ratio': '16_9',
#        'url': 'https://s1.ticketm.net/dam/c/797/5e693c26-2881-4776-8f0c-3aa94bfa3797_106511_RETINA_PORTRAIT_16_9.jpg',
#        'width': 640,
#        'height': 360,
#        'fallback': True},
#       {'ratio': '4_3',
#        'url': 'https://s1.ticketm.net/dam/c/797/5e693c26-2881-4776-8f0c-3aa94bfa3797_106511_CUSTOM.jpg',
#        'width': 305,
#        'height': 225,
#        'fallback': True},
#       {'ratio': '16_9',
#        'url': 'https://s1.ticketm.net/dam/c/797/5e693c26-2881-4776-8f0c-3aa94bfa3797_106511_RECOMENDATION_16_9.jpg',
#        'width': 100,
#        'height': 56,
#        'fallback': True},
#       {'ratio': '16_9',
#        'url': 'https://s1.ticketm.net/dam/c/797/5e693c26-2881-4776-8f0c-3aa94bfa3797_106511_TABLET_LANDSCAPE_16_9.jpg',
#        'width': 1024,
#        'height': 576,
#        'fallback': True},
#       {'ratio': '3_2',
#        'url': 'https://s1.ticketm.net/dam/c/797/5e693c26-2881-4776-8f0c-3aa94bfa3797_106511_RETINA_PORTRAIT_3_2.jpg',
#        'width': 640,
#        'height': 427,
#        'fallback': True}],
#      'classifications': [{'primary': True,
#        'segment': {'id': 'KZFzniwnSyZfZ7v7nJ', 'name': 'Music'},
#        'genre': {'id': 'KnvZfZ7vAvv', 'name': 'Alternative'},
#        'subGenre': {'id': 'KZazBEonSMnZfZ7vAvE',
#         'name': 'Adult Alternative Pop/Rock'},
#        'type': {'id': 'KZAyXgnZfZ7v7l1', 'name': 'Group'},
#        'subType': {'id': 'KZFzBErXgnZfZ7vA71', 'name': 'Band'},
#        'family': False}],
#      'upcomingEvents': {'_total': 0, '_filtered': 0},
#      '_links': {'self': {'href': '/discovery/v2/attractions/K8vZ917O7if?locale=en-us'}}},
#     {'name': 'Everywhere at Once',
#      'type': 'attraction',
#      'id': 'K8vZ917L9i0',
#      'test': False,
#      'url': 'https://www.ticketmaster.com/everywhere-at-once-tickets/artist/4241369',
#      'locale': 'en-us',
#      'images': [{'ratio': '16_9',
#        'url': 'https://s1.ticketm.net/dam/a/ee7/50efe1c1-bfd7-405d-8d6b-3b8208abeee7_TABLET_LANDSCAPE_LARGE_16_9.jpg',
#        'width': 2048,
#        'height': 1152,
#        'fallback': False},
#       {'ratio': '4_3',
#        'url': 'https://s1.ticketm.net/dam/a/ee7/50efe1c1-bfd7-405d-8d6b-3b8208abeee7_CUSTOM.jpg',
#        'width': 305,
#        'height': 225,
#        'fallback': False},
#       {'ratio': '16_9',
#        'url': 'https://s1.ticketm.net/dam/a/ee7/50efe1c1-bfd7-405d-8d6b-3b8208abeee7_RECOMENDATION_16_9.jpg',
#        'width': 100,
#        'height': 56,
#        'fallback': False},
#       {'ratio': '3_2',
#        'url': 'https://s1.ticketm.net/dam/a/ee7/50efe1c1-bfd7-405d-8d6b-3b8208abeee7_RETINA_PORTRAIT_3_2.jpg',
#        'width': 640,
#        'height': 427,
#        'fallback': False},
#       {'ratio': '3_2',
#        'url': 'https://s1.ticketm.net/dam/a/ee7/50efe1c1-bfd7-405d-8d6b-3b8208abeee7_ARTIST_PAGE_3_2.jpg',
#        'width': 305,
#        'height': 203,
#        'fallback': False},
#       {'ratio': '16_9',
#        'url': 'https://s1.ticketm.net/dam/a/ee7/50efe1c1-bfd7-405d-8d6b-3b8208abeee7_RETINA_PORTRAIT_16_9.jpg',
#        'width': 640,
#        'height': 360,
#        'fallback': False},
#       {'ratio': '3_2',
#        'url': 'https://s1.ticketm.net/dam/a/ee7/50efe1c1-bfd7-405d-8d6b-3b8208abeee7_TABLET_LANDSCAPE_3_2.jpg',
#        'width': 1024,
#        'height': 683,
#        'fallback': False},
#       {'ratio': '16_9',
#        'url': 'https://s1.ticketm.net/dam/a/ee7/50efe1c1-bfd7-405d-8d6b-3b8208abeee7_EVENT_DETAIL_PAGE_16_9.jpg',
#        'width': 205,
#        'height': 115,
#        'fallback': False},
#       {'ratio': '16_9',
#        'url': 'https://s1.ticketm.net/dam/a/ee7/50efe1c1-bfd7-405d-8d6b-3b8208abeee7_TABLET_LANDSCAPE_16_9.jpg',
#        'width': 1024,
#        'height': 576,
#        'fallback': False},
#       {'ratio': '16_9',
#        'url': 'https://s1.ticketm.net/dam/a/ee7/50efe1c1-bfd7-405d-8d6b-3b8208abeee7_RETINA_LANDSCAPE_16_9.jpg',
#        'width': 1136,
#        'height': 639,
#        'fallback': False},
#       {'ratio': '1_1',
#        'url': 'https://s1.ticketm.net/dam/a/ee7/50efe1c1-bfd7-405d-8d6b-3b8208abeee7_SOURCE',
#        'width': 4688,
#        'height': 4688,
#        'fallback': False}],
#      'classifications': [{'primary': True,
#        'segment': {'id': 'KZFzniwnSyZfZ7v7nJ', 'name': 'Music'},
#        'genre': {'id': 'KnvZfZ7vAvl', 'name': 'Other'},
#        'subGenre': {'id': 'KZazBEonSMnZfZ7vk1I', 'name': 'Other'},
#        'type': {'id': 'KZAyXgnZfZ7v7lt', 'name': 'Event Style'},
#        'subType': {'id': 'KZFzBErXgnZfZ7vA6E', 'name': 'Festival'},
#        'family': False}],
#      'upcomingEvents': {'universe': 2, '_total': 2, '_filtered': 0},
#      '_links': {'self': {'href': '/discovery/v2/attractions/K8vZ917L9i0?locale=en-us'}}}]}}]

# %%
def flatten_event(raw: dict) -> dict:
    """
    Extract the fields we care about from a raw Ticketmaster event dict
    and return them as a flat dictionary ready for validation.

    All values are kept as their native types (strings, bools) — type
    coercion is handled downstream by the Pydantic model.

    Args:
        raw: A single event object from the Ticketmaster API response,
             i.e. one item from data['_embedded']['events'].

    Returns:
        Flat dict with the fields defined in the output schema.
    """
    classifications = raw.get('classifications', [{}])[0]
    venues          = raw.get('_embedded', {}).get('venues', [{}])
    venue           = venues[0] if venues else {}
    location        = venue.get('location', {})
    start           = raw.get('dates', {}).get('start', {})

    return {
        'event_id':        raw.get('id'),
        'name':            raw.get('name'),
        'date':            start.get('localDate'),
        'time':            start.get('localTime') if not start.get('timeTBA') else None,
        'multi_day_event': raw.get('dates', {}).get('spanMultipleDays'),
        'city':            venue.get('city', {}).get('name'),
        'longitude':       location.get('longitude'),
        'latitude':        location.get('latitude'),
        'venue':           venue.get('name'),
        'capacity':        None,
        'segment':         classifications.get('segment', {}).get('name'),
        'genre':           classifications.get('genre', {}).get('name'),
        'sub_genre':       classifications.get('subGenre', {}).get('name'),
    }

# %%
flat_events = []

for event in events:
  flat_event = flatten_event(event)
  flat_events.append(flat_event)

flat_events
# Out:
# [{'event_id': 'ZxqgVMyxjZBYPJzwisVEJswJSIcnzynMZ6k1',
#   'name': 'Row C Start',
#   'date': '2024-05-25',
#   'time': '19:30:00',
#   'multi_day_event': False,
#   'city': 'Manchester',
#   'longitude': '-2.24406600',
#   'latitude': '53.48816400',
#   'venue': 'AO Arena',
#   'capacity': None,
#   'segment': None,
#   'genre': None,
#   'sub_genre': None},
#  {'event_id': 'LvZ18QxAj1bZeL8vGSGnc',
#   'name': 'EVERYWHERE AT ONCE: Dewin',
#   'date': '2026-06-28',
#   'time': '19:00:00',
#   'multi_day_event': False,
#   'city': 'Narberth, Pembrokeshire',
#   'longitude': '-4.74420400',
#   'latitude': '51.79891500',
#   'venue': 'Queens Hall',
#   'capacity': None,
#   'segment': 'Music',
#   'genre': 'Alternative',
#   'sub_genre': 'Adult Alternative Pop/Rock'}]

# %%
import time
import requests

WIKIDATA_SPARQL = 'https://query.wikidata.org/sparql'
WIKIDATA_DELAY  = 0.5  # seconds between requests — Wikidata asks for polite usage

# In-memory cache: venue name, capacity (or None if not found)
# Persists for the duration of the pipeline run so each unique venue
# is only looked up once, regardless of how many events are held there.
_capacity_cache = {}

def get_venue_capacity(session: requests.Session, venue_name: str) -> int | None:
    """
    Look up the seating capacity (Wikidata property P1083) for a venue
    by its English label using a SPARQL query.

    Results are cached in memory — repeated calls for the same venue name
    return immediately without hitting the API again.

    Args:
        session:     A shared requests.Session object.
        venue_name:  The venue name string from the Ticketmaster response,
                     e.g. "Tottenham Hotspur Stadium".

    Returns:
        Integer capacity if found, None otherwise.
    """
    # Return cached result if we've seen this venue before
    if venue_name in _capacity_cache:
        return _capacity_cache[venue_name]

    # Escape any double-quotes in the venue name to keep the SPARQL string valid
    safe_name = venue_name.replace('"', '\\"')

    query = f"""
SELECT ?capacity WHERE {{
  # ?venue rdfs:label "{safe_name}"@en .
  # ?venue wdt:P1083 ?capacity .
}}
LIMIT 1
"""

    headers = {'User-Agent': 'EventIntelligencePipeline/1.0'}

    try:
        time.sleep(WIKIDATA_DELAY)
        response = session.get(
            WIKIDATA_SPARQL,
            params={'query': query, 'format': 'json'},
            headers=headers,
            timeout=15,
        )
        response.raise_for_status()

        bindings = response.json().get('results', {}).get('bindings', [])

        if bindings and 'capacity' in bindings[0]:
            capacity = int(bindings[0]['capacity']['value'])
            _capacity_cache[venue_name] = capacity
            return capacity

    except (requests.exceptions.RequestException, ValueError, KeyError) as e:
        print(f'  Wikidata lookup failed for "{venue_name}": {e}')

    # Cache the miss too — avoids retrying venues that aren't on Wikidata
    _capacity_cache[venue_name] = None
    return None

# %%
for flat_event in flat_events:
  get_venue_capacity(session=requests.session(), venue_name=flat_event['name'])

# %%
flat_events
# Out:
# [{'event_id': 'ZxqgVMyxjZBYPJzwisVEJswJSIcnzynMZ6k1',
#   'name': 'Row C Start',
#   'date': '2024-05-25',
#   'time': '19:30:00',
#   'multi_day_event': False,
#   'city': 'Manchester',
#   'longitude': '-2.24406600',
#   'latitude': '53.48816400',
#   'venue': 'AO Arena',
#   'capacity': None,
#   'segment': None,
#   'genre': None,
#   'sub_genre': None},
#  {'event_id': 'LvZ18QxAj1bZeL8vGSGnc',
#   'name': 'EVERYWHERE AT ONCE: Dewin',
#   'date': '2026-06-28',
#   'time': '19:00:00',
#   'multi_day_event': False,
#   'city': 'Narberth, Pembrokeshire',
#   'longitude': '-4.74420400',
#   'latitude': '51.79891500',
#   'venue': 'Queens Hall',
#   'capacity': None,
#   'segment': 'Music',
#   'genre': 'Alternative',
#   'sub_genre': 'Adult Alternative Pop/Rock'}]

# %%
from pydantic import ValidationError
from models import EventRecord

def validate_event(flat: dict) -> EventRecord | None:
    """
    Validate a flattened event dict against the EventRecord Pydantic model.

    Type coercion (string → date, string → float, etc.) is handled by the
    model itself. This function just attempts construction and returns None
    if validation fails, so the caller can skip bad records without crashing.

    Args:
        flat: A flat event dict as returned by flatten_event().

    Returns:
        A validated EventRecord instance, or None if validation fails.
    """
    try:
        return EventRecord(**flat)
    except ValidationError as e:
        print(f'Validation failed for event "{flat.get("event_id")}": {e.error_count()} error(s)')
        print(e)
        return None

# %%
for flat_event in flat_events:
  print(validate_event(flat_event))
# Out:
# Validation failed for event "ZxqgVMyxjZBYPJzwisVEJswJSIcnzynMZ6k1": 1 error(s)
# 1 validation error for EventRecord
# segment
#   Input should be a valid string [type=string_type, input_value=None, input_type=NoneType]
#     For further information visit https://errors.pydantic.dev/2.13/v/string_type
# None
# event_id='LvZ18QxAj1bZeL8vGSGnc' name='EVERYWHERE AT ONCE: Dewin' date=datetime.date(2026, 6, 28) time=datetime.time(19, 0) multi_day_event=False city='Narberth, Pembrokeshire' longitude=-4.744204 latitude=51.798915 venue='Queens Hall' capacity=None segment='Music' genre='Alternative' sub_genre='Adult Alternative Pop/Rock'

# %%
import csv
from pathlib import Path

DATA_DIR    = Path('data')
OUTPUT_FILE = DATA_DIR / 'events.csv'

CSV_COLUMNS = [
    'event_id', 'name', 'date', 'time', 'multi_day_event',
    'city', 'longitude', 'latitude',
    'venue', 'capacity',
    'segment', 'genre', 'sub_genre',
]

def write_csv(records: list[dict]) -> None:
    """Write all collected records to the output CSV."""
    DATA_DIR.mkdir(exist_ok=True)
    with OUTPUT_FILE.open('w', newline='', encoding='utf-8') as f:
        writer = csv.DictWriter(f, fieldnames=CSV_COLUMNS, extrasaction='ignore')
        writer.writeheader()
        writer.writerows(records)
    print(f'Wrote {len(records)} records to {OUTPUT_FILE}')

def run_pipeline(fetch_capacity: bool = True) -> None: # fetch_capacity flag will skip fetching venue capacity if set to true.
    """
    Orchestrate the full ingestion pipeline:
      1. Build date windows across the next 12 months
      2. For each window, fetch events and filter out already-seen IDs
      3. Flatten, enrich with venue capacity, and validate each event
      4. Write the final CSV once all windows are processed

    Args:
        fetch_capacity: Set to False to skip Wikidata lookups. Useful for
                        a quick test run where capacity data isn't needed yet.
    """
    DATA_DIR.mkdir(exist_ok=True)

    session           = requests.Session()
    seen_ids:  set[str]  = set()
    collected: list[dict] = []
    validation_errors = 0

    windows = build_date_windows(months=2, window_months=2)

    for idx, (start_dt, end_dt) in enumerate(windows, 1):
        print(f'\nWindow {idx}/{len(windows)}: {start_dt[:10]} to {end_dt[:10]} '
              f'(collected so far: {len(collected)})')

        raw_events = fetch_events(start_dt, end_dt, seen_ids)

        for raw in raw_events:
            flat = flatten_event(raw)

            if fetch_capacity and flat.get('venue'):
                flat['capacity'] = get_venue_capacity(session, flat['venue'])

            record = validate_event(flat)

            if record is None:
                validation_errors += 1
                continue

            collected.append(record.model_dump())

        print(f'Window {idx} done | total collected: {len(collected)}')

    print(f'\nPipeline complete | valid: {len(collected)} | '
          f'validation errors: {validation_errors}')

    write_csv(collected)

# %%
# run_pipeline(fetch_capacity=True)

# %% [markdown]
# ## Cleaning Event Data

# %%
import pandas as pd
events = pd.read_csv('data/events.csv')
events.head()
# Out:
#    Unnamed: 0               event_id  \
# 0           0  LvZ18QxAj1bZeL8vGSGnc
# 1           1        1AdfZ_6GkTNNBkA
# 2           2        16djZ_6GAG7lrqu
# 3           3        17uOv0G65nt_3EX
# 4           4        17uOv0G6CLCvfvF
#
#                                             name        date      time  \
# 0                      EVERYWHERE AT ONCE: Dewin  2026-06-28  19:00:00
# 1           Sea Life Birmingham - Standard Entry  2026-07-09  09:30:00
# 2         Sea Life Brighton - Standard Admission  2026-07-09  10:00:00
# 3  Chessington World of Adventures - 1 Day Entry  2026-07-09  10:00:00
# 4               London Eye - Standard Experience  2026-07-09  10:00:00
#
#    multi_day_event                     city  longitude   latitude  \
# 0            False  Narberth, Pembrokeshire  -4.744204  51.798915
# 1            False               Birmingham  -1.913321  52.479053
# 2            False                 Brighton  -0.135774  50.819629
# 3            False                   Surrey  -0.311890  51.355030
# 4            False                   London  -0.117350  51.500992
#
#                                  venue  capacity        segment        genre  \
# 0                          Queens Hall        -1          Music  Alternative
# 1  National SEA LIFE Centre Birmingham        -1  Miscellaneous       Family
# 2                    SEA LIFE Brighton        -1  Miscellaneous       Family
# 3      Chessington World of Adventures        -1  Miscellaneous       Family
# 4                       The London Eye        -1  Miscellaneous       Family
#
#                     sub_genre  major_venue
# 0  Adult Alternative Pop/Rock        False
# 1                       Other        False
# 2                       Other        False
# 3                       Other        False
# 4                       Other        False

# %%
events[events['genre'].isnull()].sample(5)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 events[events['genre'].isnull()].sample(5)
#
# File c:\Users\benke\OneDrive\Documents\df-frontier\projects\event-intelligence\event-intelligence\Lib\site-packages\pandas\core\generic.py:6000, in NDFrame.sample(self, n, frac, replace, weights, random_state, axis, ignore_index)
#    5996
#    5997         if weights is not None:
#    5998             weights = sample.preprocess_weights(self, weights, axis)
#    5999
# -> 6000         sampled_indices = sample.sample(obj_len, size, replace, weights, rs)
#    6001         result = self.take(sampled_indices, axis=axis)
#    6002
#    6003         if ignore_index:
#
# File c:\Users\benke\OneDrive\Documents\df-frontier\projects\event-intelligence\event-intelligence\Lib\site-packages\pandas\core\sample.py:161, in sample(obj_len, size, replace, weights, random_state)
#     154     if not replace and size * weights.max() > 1:
#     155         raise ValueError(
#     156             "Weighted sampling cannot be achieved with replace=False. Either "
#     157             "set replace=True or use smaller weights. See the docstring of "
#     158             "sample for details."
#     159         )
# --> 161 return random_state.choice(obj_len, size=size, replace=replace, p=weights).astype(
#     162     np.intp, copy=False
#     163 )
#
# File numpy/random/mtrand.pyx:969, in numpy.random.mtrand.RandomState.choice()
# --> 969 'Could not get source, probably due dynamically evaluated source code.'
#
# ValueError: a must be greater than 0 unless no samples are taken

# %%
events.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 7124 entries, 0 to 7123
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   event_id         7124 non-null   str
#  1   name             7124 non-null   str
#  2   date             7124 non-null   str
#  3   time             7038 non-null   str
#  4   multi_day_event  7124 non-null   bool
#  5   city             7124 non-null   str
#  6   longitude        7072 non-null   float64
#  7   latitude         7072 non-null   float64
#  8   venue            7124 non-null   str
#  9   capacity         1081 non-null   float64
#  10  segment          7124 non-null   str
#  11  genre            6861 non-null   str
#  12  sub_genre        6861 non-null   str
# dtypes: bool(1), float64(3), str(9)
# memory usage: 1.4 MB

# %% [markdown]
# * date and time should be stored as `datetime` objects.
# * capacity as `int`
# * segment, genre and sub_genre as `category`

# %%
events['segment'].unique()
# Out:
# <ArrowStringArray>
# ['Music', 'Miscellaneous', 'Undefined', 'Arts & Theatre', 'Sports', 'Film']
# Length: 6, dtype: str

# %%
events.describe(include='all')
# Out:
#                      event_id                                            name  \
# count                    7124                                            7124
# unique                   7124                                            1569
# top     LvZ18QxAj1bZeL8vGSGnc  Twist Museum - London's Home of Illusions PEAK
# freq                        1                                             511
# mean                      NaN                                             NaN
# std                       NaN                                             NaN
# min                       NaN                                             NaN
# 25%                       NaN                                             NaN
# 50%                       NaN                                             NaN
# 75%                       NaN                                             NaN
# max                       NaN                                             NaN
#
#               date      time multi_day_event    city    longitude  \
# count         7124      7038            7124    7124  7072.000000
# unique         125        69               1     212          NaN
# top     2026-07-11  19:30:00           False  London          NaN
# freq           391      1910            7124    4603          NaN
# mean           NaN       NaN             NaN     NaN    -0.766728
# std            NaN       NaN             NaN     NaN     1.268377
# min            NaN       NaN             NaN     NaN    -7.618761
# 25%            NaN       NaN             NaN     NaN    -1.260350
# 50%            NaN       NaN             NaN     NaN    -0.143196
# 75%            NaN       NaN             NaN     NaN    -0.126407
# max            NaN       NaN             NaN     NaN    14.442140
#
#            latitude         venue      capacity         segment    genre  \
# count   7072.000000          7124   1081.000000            7124     6861
# unique          NaN           696           NaN               6       50
# top             NaN  Twist Museum           NaN  Arts & Theatre  Theatre
# freq            NaN           842           NaN            3701     2659
# mean      52.072101           NaN   5488.212766             NaN      NaN
# std        1.582334           NaN   8783.846198             NaN      NaN
# min        0.000000           NaN    265.000000             NaN      NaN
# 25%       51.510022           NaN   1227.000000             NaN      NaN
# 50%       51.513669           NaN   1743.000000             NaN      NaN
# 75%       51.888861           NaN   6500.000000             NaN      NaN
# max       57.493592           NaN  90000.000000             NaN      NaN
#
#        sub_genre
# count       6861
# unique       115
# top      Musical
# freq        1824
# mean         NaN
# std          NaN
# min          NaN
# 25%          NaN
# 50%          NaN
# 75%          NaN
# max          NaN

# %% [markdown]
# ### Nulls

# %%
def null_vals(dataframe):
    """
    Show both number of nulls and the percentage of nulls in the whole column across a Pandas dataframe.
    """
    null_vals = dataframe.isnull().sum() # How many nulls in each column
    total_cnt = len(dataframe) # Total entries in the dataframe
    null_vals = pd.DataFrame(null_vals,columns=['null']) # Put the number of nulls in a single dataframe
    null_vals['percent'] = round((null_vals['null']/total_cnt)*100,2) # Round how many nulls are there, as %, of the df
    
    return null_vals.sort_values('percent', ascending=False) # Ordered from MOST to LEAST nulls

# %%
null_vals(events)
# Out:
#                  null  percent
# capacity         6043    84.83
# genre             263     3.69
# sub_genre         263     3.69
# time               86     1.21
# longitude          52     0.73
# latitude           52     0.73
# date                0     0.00
# name                0     0.00
# event_id            0     0.00
# multi_day_event     0     0.00
# city                0     0.00
# venue               0     0.00
# segment             0     0.00

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

plt.figure(figsize=(6,4))

sns.heatmap(events.isnull(), yticklabels=False, cmap='gray_r', cbar=False);

# %% [markdown]
# ### Check for Duplicates

# %%
events.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ### Dropping Redundant Columns and Null Handling

# %%
events.head()
# Out:
#                 event_id                                           name  \
# 0  LvZ18QxAj1bZeL8vGSGnc                      EVERYWHERE AT ONCE: Dewin
# 1        1AdfZ_6GkTNNBkA           Sea Life Birmingham - Standard Entry
# 2        16djZ_6GAG7lrqu         Sea Life Brighton - Standard Admission
# 3        17uOv0G65nt_3EX  Chessington World of Adventures - 1 Day Entry
# 4        17uOv0G6CLCvfvF               London Eye - Standard Experience
#
#          date      time  multi_day_event                     city  longitude  \
# 0  2026-06-28  19:00:00            False  Narberth, Pembrokeshire  -4.744204
# 1  2026-07-09  09:30:00            False               Birmingham  -1.913321
# 2  2026-07-09  10:00:00            False                 Brighton  -0.135774
# 3  2026-07-09  10:00:00            False                   Surrey  -0.311890
# 4  2026-07-09  10:00:00            False                   London  -0.117350
#
#     latitude                                venue  capacity        segment  \
# 0  51.798915                          Queens Hall       NaN          Music
# 1  52.479053  National SEA LIFE Centre Birmingham       NaN  Miscellaneous
# 2  50.819629                    SEA LIFE Brighton       NaN  Miscellaneous
# 3  51.355030      Chessington World of Adventures       NaN  Miscellaneous
# 4  51.500992                       The London Eye       NaN  Miscellaneous
#
#          genre                   sub_genre
# 0  Alternative  Adult Alternative Pop/Rock
# 1       Family                       Other
# 2       Family                       Other
# 3       Family                       Other
# 4       Family                       Other

# %%
(events['segment'] == 'Undefined').sum()
# Out:
# np.int64(263)

# %%
events['segment'].unique()
# Out:
# <ArrowStringArray>
# ['Music', 'Miscellaneous', 'Undefined', 'Arts & Theatre', 'Sports', 'Film']
# Length: 6, dtype: str

# %%
events[events['segment'] == 'Undefined'].sample(10)
# Out:
#                    event_id                                      name  \
# 2754  ZKr9uZKbZL4Ze39adZeef                               Beetlejuice
# 4530  LvZ18QNJK2Zv2zZZzflrl                               Chuck Regan
# 3817   Z3r9uZKbZL4Ze39adZFC                               Beetlejuice
# 2099  ZKr9uZKbZL4ZeoOpjZeAQ                         Disney's Hercules
# 6650  LvZ18Q-ppE-MPo8ZzCxbE  FRIDAY CHESTERTONS POLO IN THE PARK 2027
# 6949  LvZ18QNVhgDk_OX-ib4EF                              Stax of Soul
# 2082  LvZ18Q_uup7c1aOZw-loL                          Fleeting Rumours
# 5818   Z3r9uZKbZL4Ze39adZ1x                               Beetlejuice
# 660   LvZ18Q0XCxgN9qbWqMkmF        ROOFTOP DAY PARTY - SUMMER EDITION
# 4311  ZKr9uZKbZL4Ze39adZedA                               Beetlejuice
#
#             date      time  multi_day_event              city  longitude  \
# 2754  2026-11-07  14:30:00            False            London  -0.130964
# 4530  2027-01-18  19:30:00            False              York  -1.093860
# 3817  2027-01-07  19:30:00            False            London  -0.130964
# 2099  2026-09-11  19:30:00            False            London  -0.120258
# 6650  2027-06-04  12:00:00            False            London  -0.204907
# 6949  2027-06-19  19:00:00            False        Manchester  -2.234389
# 2082  2026-09-11  19:30:00            False  Stockton-on-Tees  -1.312289
# 5818  2027-03-27  15:00:00            False            London  -0.130964
# 660   2026-07-11  16:00:00            False            London  -0.115021
# 4311  2027-01-15  14:30:00            False            London  -0.130964
#
#        latitude                                   venue  capacity    segment  \
# 2754  51.513763                   Prince Edward Theatre       NaN  Undefined
# 4530  53.954833                            The Crescent       NaN  Undefined
# 3817  51.513763                   Prince Edward Theatre       NaN  Undefined
# 2099  51.513008                Theatre Royal Drury Lane    2220.0  Undefined
# 6650  51.469946                         Hurlingham Park       NaN  Undefined
# 6949  53.485235                       Band On The Wall.       NaN  Undefined
# 2082  54.564400  The Georgian Theatre, Stockton-on-Tees       NaN  Undefined
# 5818  51.513763                   Prince Edward Theatre       NaN  Undefined
# 660   51.461845                         Brixton Storeys       NaN  Undefined
# 4311  51.513763                   Prince Edward Theatre       NaN  Undefined
#
#      genre sub_genre
# 2754   NaN       NaN
# 4530   NaN       NaN
# 3817   NaN       NaN
# 2099   NaN       NaN
# 6650   NaN       NaN
# 6949   NaN       NaN
# 2082   NaN       NaN
# 5818   NaN       NaN
# 660    NaN       NaN
# 4311   NaN       NaN

# %%
events['major_venue'] = events['capacity'].apply(lambda x: True if x > 0 else False)
events.head()
# Out:
#                 event_id                                           name  \
# 0  LvZ18QxAj1bZeL8vGSGnc                      EVERYWHERE AT ONCE: Dewin
# 1        1AdfZ_6GkTNNBkA           Sea Life Birmingham - Standard Entry
# 2        16djZ_6GAG7lrqu         Sea Life Brighton - Standard Admission
# 3        17uOv0G65nt_3EX  Chessington World of Adventures - 1 Day Entry
# 4        17uOv0G6CLCvfvF               London Eye - Standard Experience
#
#          date      time  multi_day_event                     city  longitude  \
# 0  2026-06-28  19:00:00            False  Narberth, Pembrokeshire  -4.744204
# 1  2026-07-09  09:30:00            False               Birmingham  -1.913321
# 2  2026-07-09  10:00:00            False                 Brighton  -0.135774
# 3  2026-07-09  10:00:00            False                   Surrey  -0.311890
# 4  2026-07-09  10:00:00            False                   London  -0.117350
#
#     latitude                                venue  capacity        segment  \
# 0  51.798915                          Queens Hall       NaN          Music
# 1  52.479053  National SEA LIFE Centre Birmingham       NaN  Miscellaneous
# 2  50.819629                    SEA LIFE Brighton       NaN  Miscellaneous
# 3  51.355030      Chessington World of Adventures       NaN  Miscellaneous
# 4  51.500992                       The London Eye       NaN  Miscellaneous
#
#          genre                   sub_genre  major_venue
# 0  Alternative  Adult Alternative Pop/Rock        False
# 1       Family                       Other        False
# 2       Family                       Other        False
# 3       Family                       Other        False
# 4       Family                       Other        False

# %%
events[events['longitude'] > 2].index
# Out:
# Index([583, 1865, 1866, 2122], dtype='int64')

# %%
events[events['latitude'] < 50].index
# Out:
# Index([1865, 1866, 2122, 6134, 6147], dtype='int64')

# %%
def clean_events_data(data):
  
  clean = data.copy()
  
  to_drop = events[events['longitude'] > 2].index
  to_drop = to_drop.union(events[events['latitude'] < 50].index) # drop any lat/long values that are not in UK
  
  clean['segment'] = clean['segment'].replace('Undefined', np.nan)
  clean = clean.drop(index=to_drop)
  clean.dropna(subset=['segment'], inplace=True)
  clean.dropna(subset=['time'], inplace=True)
  clean.dropna(subset=['latitude', 'longitude'])
  clean['capacity'] = clean['capacity'].fillna(-1)
  
  return clean

# %%
clean_events = clean_events_data(events)

# %%
def correct_types(data):
    """
    Function to map datatypes to "correct" ones according to our exploratory findings
    ~~~
    INPUT: dataframe (old types)
    OUTPUT: dataframe (new types)
    """
    
    data_new_types = data.copy()                                                       
    data_new_types['date'] = pd.to_datetime(data_new_types['date'])                             
    data_new_types['time'] = pd.to_datetime(data_new_types['time'], format="%H:%M:%S").dt.time                        
    data_new_types['capacity'] = data_new_types['capacity'].astype(int)              
    data_new_types['segment'] = data_new_types['segment'].astype('category')
    data_new_types['genre'] = data_new_types['genre'].astype('category')
    data_new_types['sub_genre'] = data_new_types['sub_genre'].astype('category')         
    
    return data_new_types

# %%
clean_events = correct_types(clean_events)

# %%
clean_events.head()
# Out:
#                 event_id                                           name  \
# 0  LvZ18QxAj1bZeL8vGSGnc                      EVERYWHERE AT ONCE: Dewin
# 1        1AdfZ_6GkTNNBkA           Sea Life Birmingham - Standard Entry
# 2        16djZ_6GAG7lrqu         Sea Life Brighton - Standard Admission
# 3        17uOv0G65nt_3EX  Chessington World of Adventures - 1 Day Entry
# 4        17uOv0G6CLCvfvF               London Eye - Standard Experience
#
#         date      time  multi_day_event                     city  longitude  \
# 0 2026-06-28  19:00:00            False  Narberth, Pembrokeshire  -4.744204
# 1 2026-07-09  09:30:00            False               Birmingham  -1.913321
# 2 2026-07-09  10:00:00            False                 Brighton  -0.135774
# 3 2026-07-09  10:00:00            False                   Surrey  -0.311890
# 4 2026-07-09  10:00:00            False                   London  -0.117350
#
#     latitude                                venue  capacity        segment  \
# 0  51.798915                          Queens Hall        -1          Music
# 1  52.479053  National SEA LIFE Centre Birmingham        -1  Miscellaneous
# 2  50.819629                    SEA LIFE Brighton        -1  Miscellaneous
# 3  51.355030      Chessington World of Adventures        -1  Miscellaneous
# 4  51.500992                       The London Eye        -1  Miscellaneous
#
#          genre                   sub_genre  major_venue
# 0  Alternative  Adult Alternative Pop/Rock        False
# 1       Family                       Other        False
# 2       Family                       Other        False
# 3       Family                       Other        False
# 4       Family                       Other        False

# %%
clean_events.to_csv('data/events.csv')

# %%
clean_events.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 6775 entries, 0 to 7123
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   event_id         6775 non-null   str
#  1   name             6775 non-null   str
#  2   date             6775 non-null   datetime64[us]
#  3   time             6775 non-null   object
#  4   multi_day_event  6775 non-null   bool
#  5   city             6775 non-null   str
#  6   longitude        6729 non-null   float64
#  7   latitude         6729 non-null   float64
#  8   venue            6775 non-null   str
#  9   capacity         6775 non-null   int64
#  10  segment          6775 non-null   category
#  11  genre            6775 non-null   category
#  12  sub_genre        6775 non-null   category
#  13  major_venue      6775 non-null   bool
# dtypes: bool(2), category(3), datetime64[us](1), float64(2), int64(1), object(1), str(4)
# memory usage: 1.0+ MB

# %%
clean_events['capacity'] = clean_events['capacity'].apply(lambda x: np.nan if x == -1 else x)

# %%
clean_events.groupby(['segment'])['capacity'].min()
# Out:
# segment
# Arts & Theatre      265.0
# Film                  NaN
# Miscellaneous      6500.0
# Music               865.0
# Sports            11400.0
# Name: capacity, dtype: float64

# %%
clean_events['venue'].nunique()
# Out:
# 665

# %%
top_20_cities = clean_events.groupby('city')['event_id'].count().sort_values(ascending=False).head(21)

# %%
sns.barplot(top_20_cities, orient='y');

# %%
top_20_cities = top_20_cities.drop(index='London')

top_20_cities
# Out:
# city
# Glasgow                184
# Birmingham             141
# Manchester             139
# Newcastle Upon Tyne     98
# Leeds                   78
# Brighton                71
# Blackpool               71
# Bristol                 67
# Surrey                  61
# Southampton             56
# Sheffield               53
# Belfast                 51
# York                    50
# Edinburgh               49
# Liverpool               48
# Cardiff                 47
# Nottingham              45
# St Andrews              29
# Bournemouth             29
# Derby                   26
# Name: event_id, dtype: int64

# %%
top_20_cities = pd.DataFrame(top_20_cities).reset_index().rename(columns={'event_id': 'nb_events'})
top_20_cities
# Out:
#                    city  nb_events
# 0               Glasgow        184
# 1            Birmingham        141
# 2            Manchester        139
# 3   Newcastle Upon Tyne         98
# 4                 Leeds         78
# 5              Brighton         71
# 6             Blackpool         71
# 7               Bristol         67
# 8                Surrey         61
# 9           Southampton         56
# 10            Sheffield         53
# 11              Belfast         51
# 12                 York         50
# 13            Edinburgh         49
# 14            Liverpool         48
# 15              Cardiff         47
# 16           Nottingham         45
# 17           St Andrews         29
# 18          Bournemouth         29
# 19                Derby         26

# %%
def create_top_20_cities(data):
  top_20_cities = data.groupby('city')['event_id'].count().sort_values(ascending=False).head(20)
  
  return top_20_cities
